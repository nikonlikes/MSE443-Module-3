# %% [markdown]
# # Initialization

# %%
import random
def generate_random_number(seed,begin,end):
    random.seed(seed)  # Set the random seed
    return random.randint(begin, end)

# %%
import pandas as pd
import numpy as np
def saving(lst,name):
  df = pd.DataFrame(lst)

  # Saving the DataFrame to a CSV file
  df.to_csv(name, index=False, header=False)
  print(name)
  print(df)

  print("DataFrame saved to", name)

# %%
import os

sample_configs = [
    {"folder": "small sized samples",  "orders": (6, 8),     "itemtypes": (7, 8), "totes": (6, 8)},
    {"folder": "medium sized samples", "orders": (30, 35),   "itemtypes": (7, 8), "totes": (16, 20)},
    {"folder": "large sized samples",  "orders": (250, 300), "itemtypes": (7, 8), "totes": (150, 200)},
]

n_datasets = 30

for config in sample_configs:
    output_dir = config["folder"]
    os.makedirs(output_dir, exist_ok=True)
    print(f"\n{'='*60}")
    print(f"  Generating {n_datasets} datasets in '{output_dir}'")
    print(f"{'='*60}")

    for dataset_idx in range(1, n_datasets + 1):
        seed = dataset_idx * 100
        random.seed(seed)

        n_orders = random.randint(*config["orders"])
        n_itemtypes = random.randint(*config["itemtypes"])
        n_totes = random.randint(*config["totes"])

        print(f"\n--- Dataset {dataset_idx} (seed={seed}) ---")
        print(f"  n_orders={n_orders}, n_itemtypes={n_itemtypes}, n_totes={n_totes}")

        # Generate order_itemtypes and order_quantities
        order_itemtypes = [[] for _ in range(n_orders)]
        order_quantities = [[] for _ in range(n_orders)]
        for i in range(n_orders):
            order_size = random.randint(1, 3)
            tt = random.sample(range(0, n_itemtypes - 1), order_size)
            qq = [random.randint(1, 3) for _ in range(order_size)]
            order_itemtypes[i] = tt
            order_quantities[i] = qq

        # Generate orders_totes
        orders_totes = [[] for _ in range(n_orders)]
        for i in range(n_orders):
            for j in range(len(order_itemtypes[i])):
                if j == 0:
                    orders_totes[i].append(random.randint(0, n_totes - 1))
                else:
                    if random.randint(0, 1) == 0:
                        orders_totes[i].append(orders_totes[i][0])
                    else:
                        orders_totes[i].append(random.randint(0, n_totes - 1))

        # Save with incrementing filenames into the output folder
        saving(order_itemtypes, os.path.join(output_dir, f"order_itemtypes_{dataset_idx}.csv"))
        saving(orders_totes, os.path.join(output_dir, f"orders_totes_{dataset_idx}.csv"))
        saving(order_quantities, os.path.join(output_dir, f"order_quantities_{dataset_idx}.csv"))
# Out:
# === Dataset 1 (seed=100) ===
#   n_orders=31, n_itemtypes=8, n_totes=19
# medium sized samples\order_itemtypes_1.csv
#     0    1    2
# 0   5  NaN  NaN
# 1   2  3.0  4.0
# 2   5  NaN  NaN
# 3   0  5.0  NaN
# 4   1  2.0  NaN
# 5   1  NaN  NaN
# 6   5  3.0  NaN
# 7   4  2.0  NaN
# 8   5  0.0  1.0
# 9   6  NaN  NaN
# 10  1  NaN  NaN
# 11  5  NaN  NaN
# 12  6  5.0  NaN
# 13  4  0.0  6.0
# 14  5  2.0  4.0
# 15  4  2.0  NaN
# 16  6  NaN  NaN
# 17  5  3.0  NaN
# 18  5  3.0  4.0
# 19  0  NaN  NaN
# 20  6  2.0  1.0
# 21  0  5.0  6.0
# 22  4  1.0  6.0
# 23  5  NaN  NaN
# 24  1  4.0  NaN
# 25  1  0.0  3.0
# 26  5  1.0  4.0
# 27  0  5.0  3.0
# 28  1  NaN  NaN
# 29  0  NaN  NaN
# 30  1  NaN  NaN
# DataFrame saved to medium sized samples\order_itemtypes_1.csv
# medium sized samples\orders_totes_1.csv
#      0     1     2
# 0    2   NaN   NaN
# 1    3   2.0   1.0
# 2   17   NaN   NaN
# 3   13  14.0   NaN
# 4   10  16.0   NaN
# 5    6   NaN   NaN
# 6   18  13.0   NaN
# 7    4   4.0   NaN
# 8   13  13.0  12.0
# 9    8   NaN   NaN
# 10   3   NaN   NaN
# 11   6   NaN   NaN
# 12   7   7.0   NaN
# 13  12   0.0   9.0
# 14   1   1.0   7.0
# 15  12  12.0   NaN
# 16   2   NaN   NaN
# 17   7   0.0   NaN
# 18   2  10.0   1.0
# 19   5   NaN   NaN
# 20   2   2.0  17.0
# 21   4   4.0   4.0
# 22   0  16.0   5.0
# 23  12   NaN   NaN
# 24  12   6.0   NaN
# 25   6   6.0   2.0
# 26  14  14.0  18.0
# 27  18  18.0   4.0
# 28   3   NaN   NaN
# 29  18   NaN   NaN
# 30   7   NaN   NaN
# DataFrame saved to medium sized samples\orders_totes_1.csv
# medium sized samples\order_quantities_1.csv
#     0    1    2
# 0   2  NaN  NaN
# 1   1  3.0  1.0
# 2   2  NaN  NaN
# 3   3  1.0  NaN
# 4   1  1.0  NaN
# 5   2  NaN  NaN
# 6   1  2.0  NaN
# 7   2  1.0  NaN
# 8   1  3.0  2.0
# 9   3  NaN  NaN
# 10  1  NaN  NaN
# 11  1  NaN  NaN
# 12  2  1.0  NaN
# 13  1  3.0  3.0
# 14  2  3.0  3.0
# 15  2  2.0  NaN
# 16  1  NaN  NaN
# 17  2  1.0  NaN
# 18  2  3.0  2.0
# 19  3  NaN  NaN
# 20  1  2.0  3.0
# 21  3  1.0  2.0
# 22  2  2.0  2.0
# 23  1  NaN  NaN
# 24  1  3.0  NaN
# 25  3  1.0  2.0
# 26  3  3.0  2.0
# 27  1  1.0  2.0
# 28  1  NaN  NaN
# 29  1  NaN  NaN
# 30  3  NaN  NaN
# DataFrame saved to medium sized samples\order_quantities_1.csv
#
# === Dataset 2 (seed=200) ===
#   n_orders=30, n_itemtypes=7, n_totes=16
# medium sized samples\order_itemtypes_2.csv
#     0    1    2
# 0   4  NaN  NaN
# 1   5  NaN  NaN
# 2   1  0.0  3.0
# 3   1  NaN  NaN
# 4   2  NaN  NaN
# 5   3  2.0  0.0
# 6   3  2.0  0.0
# 7   3  1.0  NaN
# 8   0  4.0  NaN
# 9   5  2.0  0.0
# 10  5  NaN  NaN
# 11  4  NaN  NaN
# 12  1  3.0  NaN
# 13  2  5.0  1.0
# 14  2  4.0  NaN
# 15  5  4.0  NaN
# 16  1  NaN  NaN
# 17  2  NaN  NaN
# 18  0  5.0  3.0
# 19  0  2.0  NaN
# 20  0  1.0  NaN
# 21  5  3.0  1.0
# 22  1  NaN  NaN
# 23  0  2.0  NaN
# 24  0  NaN  NaN
# 25  4  0.0  NaN
# 26  3  NaN  NaN
# 27  3  1.0  0.0
# 28  4  5.0  NaN
# 29  1  NaN  NaN
# DataFrame saved to medium sized samples\order_itemtypes_2.csv
# medium sized samples\orders_totes_2.csv
#      0     1     2
# 0    3   NaN   NaN
# 1   14   NaN   NaN
# 2   14  14.0  14.0
# 3    0   NaN   NaN
# 4    2   NaN   NaN
# 5    6   6.0  15.0
# 6    1   1.0   1.0
# 7    7   7.0   NaN
# 8   13  13.0   NaN
# 9   14  14.0  13.0
# 10   5   NaN   NaN
# 11  12   NaN   NaN
# 12   0   0.0   NaN
# 13   1   1.0   1.0
# 14   7   4.0   NaN
# 15  13  13.0   NaN
# 16   5   NaN   NaN
# 17   4   NaN   NaN
# 18  12   0.0  12.0
# 19  15  15.0   NaN
# 20   3   3.0   NaN
# 21  14  14.0   3.0
# 22   1   NaN   NaN
# 23  12  12.0   NaN
# 24  12   NaN   NaN
# 25   5   5.0   NaN
# 26  12   NaN   NaN
# 27  14  14.0  10.0
# 28  13   7.0   NaN
# 29  14   NaN   NaN
# DataFrame saved to medium sized samples\orders_totes_2.csv
# medium sized samples\order_quantities_2.csv
#     0    1    2
# 0   2  NaN  NaN
# 1   2  NaN  NaN
# 2   2  2.0  2.0
# 3   3  NaN  NaN
# 4   3  NaN  NaN
# 5   2  2.0  1.0
# 6   3  1.0  1.0
# 7   1  2.0  NaN
# 8   1  3.0  NaN
# 9   1  3.0  3.0
# 10  3  NaN  NaN
# 11  3  NaN  NaN
# 12  2  3.0  NaN
# 13  1  1.0  3.0
# 14  2  1.0  NaN
# 15  2  3.0  NaN
# 16  3  NaN  NaN
# 17  3  NaN  NaN
# 18  2  1.0  2.0
# 19  3  2.0  NaN
# 20  1  3.0  NaN
# 21  2  2.0  1.0
# 22  3  NaN  NaN
# 23  3  2.0  NaN
# 24  1  NaN  NaN
# 25  2  1.0  NaN
# 26  1  NaN  NaN
# 27  2  2.0  1.0
# 28  3  3.0  NaN
# 29  1  NaN  NaN
# DataFrame saved to medium sized samples\order_quantities_2.csv
#
# === Dataset 3 (seed=300) ===
#   n_orders=34, n_itemtypes=8, n_totes=18
# medium sized samples\order_itemtypes_3.csv
#     0    1    2
# 0   3  NaN  NaN
# 1   6  3.0  4.0
# 2   3  NaN  NaN
# 3   4  1.0  NaN
# 4   6  NaN  NaN
# 5   6  4.0  0.0
# 6   5  4.0  NaN
# 7   4  2.0  NaN
# 8   4  NaN  NaN
# 9   2  0.0  NaN
# 10  5  NaN  NaN
# 11  0  4.0  NaN
# 12  5  NaN  NaN
# 13  3  1.0  6.0
# 14  2  3.0  5.0
# 15  5  3.0  1.0
# 16  3  5.0  1.0
# 17  2  0.0  4.0
# 18  1  NaN  NaN
# 19  4  1.0  NaN
# 20  4  3.0  0.0
# 21  0  2.0  NaN
# 22  3  NaN  NaN
# 23  0  1.0  5.0
# 24  6  3.0  NaN
# 25  3  6.0  5.0
# 26  2  5.0  NaN
# 27  1  NaN  NaN
# 28  2  6.0  NaN
# 29  5  NaN  NaN
# 30  5  0.0  6.0
# 31  1  5.0  2.0
# 32  2  1.0  6.0
# 33  6  2.0  5.0
# DataFrame saved to medium sized samples\order_itemtypes_3.csv
# medium sized samples\orders_totes_3.csv
#      0     1     2
# 0    8   NaN   NaN
# 1   13  17.0   6.0
# 2    6   NaN   NaN
# 3    6   6.0   NaN
# 4    2   NaN   NaN
# 5    3   3.0   3.0
# 6    4   4.0   NaN
# 7   12  12.0   NaN
# 8    3   NaN   NaN
# 9    3   3.0   NaN
# 10   8   NaN   NaN
# 11  11  13.0   NaN
# 12   2   NaN   NaN
# 13  10  10.0  10.0
# 14  13  10.0  10.0
# 15   3   3.0   3.0
# 16  11  11.0  11.0
# 17   4   4.0   4.0
# 18   2   NaN   NaN
# 19  13  13.0   NaN
# 20   6  15.0   6.0
# 21   0  13.0   NaN
# 22   6   NaN   NaN
# 23   4   4.0   4.0
# 24   0   0.0   NaN
# 25   8   8.0   8.0
# 26   4  13.0   NaN
# 27  14   NaN   NaN
# 28   7   7.0   NaN
# 29  11   NaN   NaN
# 30   6  15.0   6.0
# 31   1   1.0   1.0
# 32   2   2.0   8.0
# 33   7   7.0   7.0
# DataFrame saved to medium sized samples\orders_totes_3.csv
# medium sized samples\order_quantities_3.csv
#     0    1    2
# 0   2  NaN  NaN
# 1   3  1.0  1.0
# 2   2  NaN  NaN
# 3   3  1.0  NaN
# 4   3  NaN  NaN
# 5   3  1.0  2.0
# 6   1  3.0  NaN
# 7   1  1.0  NaN
# 8   1  NaN  NaN
# 9   3  1.0  NaN
# 10  2  NaN  NaN
# 11  2  3.0  NaN
# 12  3  NaN  NaN
# 13  1  2.0  1.0
# 14  1  2.0  3.0
# 15  1  1.0  2.0
# 16  3  1.0  2.0
# 17  3  1.0  2.0
# 18  1  NaN  NaN
# 19  3  2.0  NaN
# 20  2  2.0  3.0
# 21  3  1.0  NaN
# 22  1  NaN  NaN
# 23  1  1.0  1.0
# 24  2  2.0  NaN
# 25  2  3.0  3.0
# 26  3  3.0  NaN
# 27  2  NaN  NaN
# 28  1  3.0  NaN
# 29  2  NaN  NaN
# 30  1  1.0  2.0
# 31  3  2.0  3.0
# 32  3  3.0  1.0
# 33  1  3.0  2.0
# DataFrame saved to medium sized samples\order_quantities_3.csv
#
# === Dataset 4 (seed=400) ===
#   n_orders=32, n_itemtypes=8, n_totes=16
# medium sized samples\order_itemtypes_4.csv
#     0    1    2
# 0   3  6.0  5.0
# 1   3  1.0  NaN
# 2   6  NaN  NaN
# 3   6  NaN  NaN
# 4   6  0.0  3.0
# 5   6  1.0  NaN
# 6   2  NaN  NaN
# 7   5  0.0  3.0
# 8   0  NaN  NaN
# 9   1  NaN  NaN
# 10  2  0.0  4.0
# 11  0  1.0  NaN
# 12  5  3.0  NaN
# 13  5  6.0  NaN
# 14  2  NaN  NaN
# 15  5  4.0  NaN
# 16  1  2.0  NaN
# 17  0  NaN  NaN
# 18  2  NaN  NaN
# 19  4  6.0  NaN
# 20  5  NaN  NaN
# 21  3  5.0  2.0
# 22  2  4.0  3.0
# 23  4  3.0  NaN
# 24  0  6.0  NaN
# 25  0  NaN  NaN
# 26  2  NaN  NaN
# 27  2  NaN  NaN
# 28  1  NaN  NaN
# 29  6  NaN  NaN
# 30  4  6.0  3.0
# 31  0  6.0  4.0
# DataFrame saved to medium sized samples\order_itemtypes_4.csv
# medium sized samples\orders_totes_4.csv
#      0     1     2
# 0   14  10.0   7.0
# 1   11   0.0   NaN
# 2   14   NaN   NaN
# 3   13   NaN   NaN
# 4    5   5.0   5.0
# 5    4   4.0   NaN
# 6    2   NaN   NaN
# 7    5   5.0   5.0
# 8    2   NaN   NaN
# 9    2   NaN   NaN
# 10  12  12.0  12.0
# 11   5   5.0   NaN
# 12  15  15.0   NaN
# 13  10   4.0   NaN
# 14   9   NaN   NaN
# 15   5   2.0   NaN
# 16   9   9.0   NaN
# 17   1   NaN   NaN
# 18   9   NaN   NaN
# 19   9   2.0   NaN
# 20  13   NaN   NaN
# 21   4   4.0   8.0
# 22  15  15.0  15.0
# 23   1   4.0   NaN
# 24   1   1.0   NaN
# 25  12   NaN   NaN
# 26   2   NaN   NaN
# 27   2   NaN   NaN
# 28   0   NaN   NaN
# 29   7   NaN   NaN
# 30  11  11.0   4.0
# 31   9  14.0   9.0
# DataFrame saved to medium sized samples\orders_totes_4.csv
# medium sized samples\order_quantities_4.csv
#     0    1    2
# 0   2  3.0  2.0
# 1   3  2.0  NaN
# 2   3  NaN  NaN
# 3   1  NaN  NaN
# 4   2  3.0  1.0
# 5   1  1.0  NaN
# 6   1  NaN  NaN
# 7   3  3.0  3.0
# 8   1  NaN  NaN
# 9   1  NaN  NaN
# 10  2  2.0  2.0
# 11  1  2.0  NaN
# 12  3  3.0  NaN
# 13  2  3.0  NaN
# 14  3  NaN  NaN
# 15  2  1.0  NaN
# 16  3  1.0  NaN
# 17  1  NaN  NaN
# 18  3  NaN  NaN
# 19  3  2.0  NaN
# 20  2  NaN  NaN
# 21  2  3.0  3.0
# 22  1  3.0  1.0
# 23  3  3.0  NaN
# 24  1  2.0  NaN
# 25  1  NaN  NaN
# 26  2  NaN  NaN
# 27  1  NaN  NaN
# 28  2  NaN  NaN
# 29  1  NaN  NaN
# 30  3  1.0  2.0
# 31  1  3.0  3.0
# DataFrame saved to medium sized samples\order_quantities_4.csv
#
# === Dataset 5 (seed=500) ===
#   n_orders=33, n_itemtypes=8, n_totes=18
# medium sized samples\order_itemtypes_5.csv
#     0    1    2
# 0   6  5.0  3.0
# 1   5  0.0  6.0
# 2   6  2.0  NaN
# 3   3  4.0  NaN
# 4   3  NaN  NaN
# 5   2  NaN  NaN
# 6   2  NaN  NaN
# 7   3  1.0  NaN
# 8   0  1.0  3.0
# 9   3  5.0  6.0
# 10  4  6.0  3.0
# 11  5  6.0  NaN
# 12  6  NaN  NaN
# 13  2  6.0  NaN
# 14  0  NaN  NaN
# 15  4  2.0  6.0
# 16  6  5.0  NaN
# 17  2  6.0  0.0
# 18  1  NaN  NaN
# 19  4  0.0  NaN
# 20  1  NaN  NaN
# 21  4  3.0  NaN
# 22  1  4.0  NaN
# 23  0  NaN  NaN
# 24  0  4.0  5.0
# 25  3  5.0  NaN
# 26  0  4.0  NaN
# 27  1  5.0  NaN
# 28  5  0.0  4.0
# 29  5  2.0  NaN
# 30  0  6.0  NaN
# 31  3  4.0  NaN
# 32  4  1.0  5.0
# DataFrame saved to medium sized samples\order_itemtypes_5.csv
# medium sized samples\orders_totes_5.csv
#      0     1     2
# 0    2   2.0   2.0
# 1   11   1.0   6.0
# 2    6   6.0   NaN
# 3   12  12.0   NaN
# 4    8   NaN   NaN
# 5   11   NaN   NaN
# 6   10   NaN   NaN
# 7    0   0.0   NaN
# 8    8   8.0   8.0
# 9   16  17.0  16.0
# 10  13   1.0   4.0
# 11  10   2.0   NaN
# 12  12   NaN   NaN
# 13   8   8.0   NaN
# 14  17   NaN   NaN
# 15   1  11.0  10.0
# 16  11  11.0   NaN
# 17   5   2.0   4.0
# 18   0   NaN   NaN
# 19  17   3.0   NaN
# 20  15   NaN   NaN
# 21   4   4.0   NaN
# 22   7   7.0   NaN
# 23   7   NaN   NaN
# 24  17  17.0  17.0
# 25   0   0.0   NaN
# 26   9  13.0   NaN
# 27   7   7.0   NaN
# 28   8   8.0   6.0
# 29  13  13.0   NaN
# 30   1   1.0   NaN
# 31   1   7.0   NaN
# 32   1   1.0   1.0
# DataFrame saved to medium sized samples\orders_totes_5.csv
# medium sized samples\order_quantities_5.csv
#     0    1    2
# 0   1  1.0  2.0
# 1   1  2.0  1.0
# 2   1  1.0  NaN
# 3   2  2.0  NaN
# 4   1  NaN  NaN
# 5   3  NaN  NaN
# 6   2  NaN  NaN
# 7   3  1.0  NaN
# 8   2  3.0  1.0
# 9   3  2.0  1.0
# 10  2  3.0  3.0
# 11  3  3.0  NaN
# 12  2  NaN  NaN
# 13  2  3.0  NaN
# 14  2  NaN  NaN
# 15  2  1.0  3.0
# 16  2  1.0  NaN
# 17  1  1.0  1.0
# 18  3  NaN  NaN
# 19  3  2.0  NaN
# 20  3  NaN  NaN
# 21  2  2.0  NaN
# 22  2  3.0  NaN
# 23  1  NaN  NaN
# 24  2  1.0  2.0
# 25  1  2.0  NaN
# 26  3  2.0  NaN
# 27  3  1.0  NaN
# 28  3  3.0  1.0
# 29  2  2.0  NaN
# 30  3  3.0  NaN
# 31  2  3.0  NaN
# 32  2  1.0  2.0
# DataFrame saved to medium sized samples\order_quantities_5.csv
#
# === Dataset 6 (seed=600) ===
#   n_orders=32, n_itemtypes=8, n_totes=19
# medium sized samples\order_itemtypes_6.csv
#     0    1    2
# 0   4  NaN  NaN
# 1   3  6.0  NaN
# 2   0  4.0  6.0
# 3   2  0.0  NaN
# 4   1  NaN  NaN
# 5   0  NaN  NaN
# 6   5  4.0  1.0
# 7   5  3.0  4.0
# 8   2  0.0  4.0
# 9   4  0.0  6.0
# 10  5  NaN  NaN
# 11  6  2.0  NaN
# 12  0  NaN  NaN
# 13  5  NaN  NaN
# 14  3  4.0  5.0
# 15  5  1.0  4.0
# 16  5  NaN  NaN
# 17  2  NaN  NaN
# 18  5  4.0  6.0
# 19  1  5.0  0.0
# 20  5  1.0  4.0
# 21  4  NaN  NaN
# 22  2  5.0  6.0
# 23  0  NaN  NaN
# 24  6  NaN  NaN
# 25  5  2.0  NaN
# 26  2  NaN  NaN
# 27  3  2.0  1.0
# 28  3  5.0  4.0
# 29  2  NaN  NaN
# 30  4  0.0  NaN
# 31  6  NaN  NaN
# DataFrame saved to medium sized samples\order_itemtypes_6.csv
# medium sized samples\orders_totes_6.csv
#      0     1     2
# 0    3   NaN   NaN
# 1   16  16.0   NaN
# 2    7   7.0   2.0
# 3    4   4.0   NaN
# 4   13   NaN   NaN
# 5   17   NaN   NaN
# 6   16   8.0  16.0
# 7    6  12.0   0.0
# 8   16  14.0   2.0
# 9   17   8.0  17.0
# 10  11   NaN   NaN
# 11   9   9.0   NaN
# 12  10   NaN   NaN
# 13   0   NaN   NaN
# 14  11   5.0  11.0
# 15   0   1.0   0.0
# 16   2   NaN   NaN
# 17   5   NaN   NaN
# 18  18  18.0  18.0
# 19  17  17.0  17.0
# 20   8   8.0   8.0
# 21  10   NaN   NaN
# 22   4   4.0   4.0
# 23   0   NaN   NaN
# 24   8   NaN   NaN
# 25   9   8.0   NaN
# 26  13   NaN   NaN
# 27  12  10.0   5.0
# 28   7  11.0   4.0
# 29  15   NaN   NaN
# 30  11   0.0   NaN
# 31   9   NaN   NaN
# DataFrame saved to medium sized samples\orders_totes_6.csv
# medium sized samples\order_quantities_6.csv
#     0    1    2
# 0   1  NaN  NaN
# 1   2  1.0  NaN
# 2   3  2.0  3.0
# 3   1  1.0  NaN
# 4   3  NaN  NaN
# 5   2  NaN  NaN
# 6   2  1.0  2.0
# 7   3  2.0  1.0
# 8   3  1.0  2.0
# 9   3  1.0  2.0
# 10  1  NaN  NaN
# 11  2  3.0  NaN
# 12  1  NaN  NaN
# 13  1  NaN  NaN
# 14  3  2.0  2.0
# 15  3  2.0  1.0
# 16  1  NaN  NaN
# 17  2  NaN  NaN
# 18  1  2.0  3.0
# 19  2  3.0  1.0
# 20  3  1.0  2.0
# 21  1  NaN  NaN
# 22  2  1.0  2.0
# 23  3  NaN  NaN
# 24  3  NaN  NaN
# 25  3  1.0  NaN
# 26  3  NaN  NaN
# 27  3  2.0  2.0
# 28  3  2.0  3.0
# 29  2  NaN  NaN
# 30  3  2.0  NaN
# 31  3  NaN  NaN
# DataFrame saved to medium sized samples\order_quantities_6.csv
#
# === Dataset 7 (seed=700) ===
#   n_orders=31, n_itemtypes=7, n_totes=19
# medium sized samples\order_itemtypes_7.csv
#     0    1    2
# 0   1  4.0  2.0
# 1   4  NaN  NaN
# 2   2  NaN  NaN
# 3   1  4.0  NaN
# 4   5  2.0  NaN
# 5   0  NaN  NaN
# 6   0  NaN  NaN
# 7   3  4.0  0.0
# 8   4  0.0  1.0
# 9   0  3.0  NaN
# 10  2  NaN  NaN
# 11  2  4.0  NaN
# 12  5  3.0  NaN
# 13  4  NaN  NaN
# 14  3  1.0  4.0
# 15  3  0.0  NaN
# 16  5  2.0  NaN
# 17  1  4.0  5.0
# 18  0  3.0  1.0
# 19  1  NaN  NaN
# 20  5  0.0  NaN
# 21  3  0.0  4.0
# 22  5  NaN  NaN
# 23  1  3.0  NaN
# 24  1  4.0  NaN
# 25  3  1.0  NaN
# 26  2  0.0  3.0
# 27  5  0.0  NaN
# 28  4  3.0  2.0
# 29  5  1.0  NaN
# 30  3  2.0  5.0
# DataFrame saved to medium sized samples\order_itemtypes_7.csv
# medium sized samples\orders_totes_7.csv
#      0     1     2
# 0   16   2.0   4.0
# 1    7   NaN   NaN
# 2   12   NaN   NaN
# 3    7   7.0   NaN
# 4   14  18.0   NaN
# 5   14   NaN   NaN
# 6    9   NaN   NaN
# 7    3   3.0   3.0
# 8    9   9.0   9.0
# 9   15  15.0   NaN
# 10  11   NaN   NaN
# 11  13  13.0   NaN
# 12  11  11.0   NaN
# 13  13   NaN   NaN
# 14   3   4.0   3.0
# 15  10  10.0   NaN
# 16   1   1.0   NaN
# 17  12  18.0  12.0
# 18   3   8.0  13.0
# 19   7   NaN   NaN
# 20   6   6.0   NaN
# 21  15  15.0  15.0
# 22  14   NaN   NaN
# 23  13  13.0   NaN
# 24  17   3.0   NaN
# 25  10  18.0   NaN
# 26   5   5.0   4.0
# 27  15  13.0   NaN
# 28   3   0.0   3.0
# 29  12  12.0   NaN
# 30   6   6.0   6.0
# DataFrame saved to medium sized samples\orders_totes_7.csv
# medium sized samples\order_quantities_7.csv
#     0    1    2
# 0   1  3.0  3.0
# 1   1  NaN  NaN
# 2   3  NaN  NaN
# 3   3  2.0  NaN
# 4   3  2.0  NaN
# 5   3  NaN  NaN
# 6   2  NaN  NaN
# 7   2  1.0  2.0
# 8   3  2.0  1.0
# 9   2  3.0  NaN
# 10  3  NaN  NaN
# 11  1  3.0  NaN
# 12  2  1.0  NaN
# 13  3  NaN  NaN
# 14  2  2.0  1.0
# 15  3  1.0  NaN
# 16  3  1.0  NaN
# 17  3  3.0  1.0
# 18  2  2.0  2.0
# 19  2  NaN  NaN
# 20  1  2.0  NaN
# 21  3  3.0  1.0
# 22  2  NaN  NaN
# 23  2  2.0  NaN
# 24  1  1.0  NaN
# 25  1  2.0  NaN
# 26  1  3.0  2.0
# 27  2  3.0  NaN
# 28  2  1.0  1.0
# 29  2  1.0  NaN
# 30  1  2.0  1.0
# DataFrame saved to medium sized samples\order_quantities_7.csv
#
# === Dataset 8 (seed=800) ===
#   n_orders=35, n_itemtypes=8, n_totes=20
# medium sized samples\order_itemtypes_8.csv
#     0    1    2
# 0   3  NaN  NaN
# 1   2  5.0  0.0
# 2   0  NaN  NaN
# 3   6  NaN  NaN
# 4   3  1.0  NaN
# 5   2  0.0  NaN
# 6   4  1.0  NaN
# 7   0  5.0  4.0
# 8   4  NaN  NaN
# 9   4  NaN  NaN
# 10  1  4.0  2.0
# 11  2  6.0  5.0
# 12  5  4.0  NaN
# 13  4  3.0  NaN
# 14  4  NaN  NaN
# 15  2  3.0  6.0
# 16  4  3.0  5.0
# 17  0  5.0  NaN
# 18  2  6.0  NaN
# 19  1  0.0  NaN
# 20  4  0.0  NaN
# 21  6  NaN  NaN
# 22  3  NaN  NaN
# 23  2  NaN  NaN
# 24  5  1.0  NaN
# 25  0  2.0  NaN
# 26  0  2.0  NaN
# 27  0  NaN  NaN
# 28  2  4.0  NaN
# 29  6  0.0  NaN
# 30  6  5.0  4.0
# 31  3  NaN  NaN
# 32  0  4.0  3.0
# 33  6  3.0  NaN
# 34  5  3.0  6.0
# DataFrame saved to medium sized samples\order_itemtypes_8.csv
# medium sized samples\orders_totes_8.csv
#      0     1     2
# 0   16   NaN   NaN
# 1    1   1.0   1.0
# 2    7   NaN   NaN
# 3   18   NaN   NaN
# 4    1  14.0   NaN
# 5   15   4.0   NaN
# 6   12   2.0   NaN
# 7   10  10.0  10.0
# 8    7   NaN   NaN
# 9    1   NaN   NaN
# 10  17  11.0  17.0
# 11  18   6.0  18.0
# 12  10   1.0   NaN
# 13  18   1.0   NaN
# 14   9   NaN   NaN
# 15   3   5.0  11.0
# 16  12  12.0   2.0
# 17   9   9.0   NaN
# 18   3   3.0   NaN
# 19  16   4.0   NaN
# 20   2   2.0   NaN
# 21   1   NaN   NaN
# 22   3   NaN   NaN
# 23   9   NaN   NaN
# 24  14  14.0   NaN
# 25  10   1.0   NaN
# 26   5   5.0   NaN
# 27  13   NaN   NaN
# 28  15  16.0   NaN
# 29   5   5.0   NaN
# 30  11  12.0  11.0
# 31  13   NaN   NaN
# 32   0   0.0  19.0
# 33   7   9.0   NaN
# 34  10   1.0  12.0
# DataFrame saved to medium sized samples\orders_totes_8.csv
# medium sized samples\order_quantities_8.csv
#     0    1    2
# 0   2  NaN  NaN
# 1   2  1.0  3.0
# 2   3  NaN  NaN
# 3   3  NaN  NaN
# 4   2  2.0  NaN
# 5   1  1.0  NaN
# 6   3  1.0  NaN
# 7   1  3.0  1.0
# 8   1  NaN  NaN
# 9   3  NaN  NaN
# 10  2  3.0  3.0
# 11  1  3.0  3.0
# 12  2  3.0  NaN
# 13  3  1.0  NaN
# 14  1  NaN  NaN
# 15  3  2.0  3.0
# 16  1  3.0  3.0
# 17  2  3.0  NaN
# 18  3  3.0  NaN
# 19  2  2.0  NaN
# 20  1  2.0  NaN
# 21  1  NaN  NaN
# 22  2  NaN  NaN
# 23  1  NaN  NaN
# 24  1  3.0  NaN
# 25  3  1.0  NaN
# 26  2  3.0  NaN
# 27  3  NaN  NaN
# 28  2  3.0  NaN
# 29  2  1.0  NaN
# 30  2  1.0  2.0
# 31  3  NaN  NaN
# 32  2  3.0  2.0
# 33  3  1.0  NaN
# 34  3  1.0  1.0
# DataFrame saved to medium sized samples\order_quantities_8.csv
#
# === Dataset 9 (seed=900) ===
#   n_orders=34, n_itemtypes=7, n_totes=18
# medium sized samples\order_itemtypes_9.csv
#     0    1    2
# 0   5  NaN  NaN
# 1   1  2.0  0.0
# 2   3  4.0  2.0
# 3   0  3.0  2.0
# 4   5  1.0  0.0
# 5   1  NaN  NaN
# 6   1  NaN  NaN
# 7   2  3.0  NaN
# 8   3  NaN  NaN
# 9   0  2.0  3.0
# 10  4  NaN  NaN
# 11  3  NaN  NaN
# 12  0  NaN  NaN
# 13  4  1.0  NaN
# 14  4  0.0  NaN
# 15  5  4.0  0.0
# 16  3  NaN  NaN
# 17  1  4.0  0.0
# 18  0  NaN  NaN
# 19  5  2.0  1.0
# 20  0  1.0  4.0
# 21  3  0.0  5.0
# 22  0  5.0  4.0
# 23  2  NaN  NaN
# 24  2  NaN  NaN
# 25  5  1.0  0.0
# 26  1  0.0  NaN
# 27  3  1.0  NaN
# 28  5  3.0  NaN
# 29  4  NaN  NaN
# 30  1  3.0  NaN
# 31  5  3.0  NaN
# 32  0  3.0  5.0
# 33  2  1.0  NaN
# DataFrame saved to medium sized samples\order_itemtypes_9.csv
# medium sized samples\orders_totes_9.csv
#      0     1     2
# 0   13   NaN   NaN
# 1    4   4.0   4.0
# 2    1   2.0   8.0
# 3    2   2.0   2.0
# 4   16  16.0  16.0
# 5    1   NaN   NaN
# 6   15   NaN   NaN
# 7   13   1.0   NaN
# 8    9   NaN   NaN
# 9    3   2.0   0.0
# 10   4   NaN   NaN
# 11  16   NaN   NaN
# 12   3   NaN   NaN
# 13  11   0.0   NaN
# 14   2   2.0   NaN
# 15   4   4.0   4.0
# 16  16   NaN   NaN
# 17   1   2.0   1.0
# 18  17   NaN   NaN
# 19   8   8.0   3.0
# 20  10  10.0   6.0
# 21  15  17.0   4.0
# 22   7   2.0  12.0
# 23  17   NaN   NaN
# 24   2   NaN   NaN
# 25  10  10.0  10.0
# 26   8   8.0   NaN
# 27   5   5.0   NaN
# 28   9   9.0   NaN
# 29  12   NaN   NaN
# 30   3   3.0   NaN
# 31   6   5.0   NaN
# 32  15  12.0   2.0
# 33  10   5.0   NaN
# DataFrame saved to medium sized samples\orders_totes_9.csv
# medium sized samples\order_quantities_9.csv
#     0    1    2
# 0   1  NaN  NaN
# 1   1  2.0  1.0
# 2   2  3.0  1.0
# 3   3  2.0  1.0
# 4   3  3.0  2.0
# 5   1  NaN  NaN
# 6   2  NaN  NaN
# 7   3  3.0  NaN
# 8   3  NaN  NaN
# 9   2  1.0  2.0
# 10  1  NaN  NaN
# 11  3  NaN  NaN
# 12  2  NaN  NaN
# 13  1  2.0  NaN
# 14  3  1.0  NaN
# 15  3  1.0  2.0
# 16  1  NaN  NaN
# 17  1  2.0  1.0
# 18  2  NaN  NaN
# 19  3  2.0  2.0
# 20  2  1.0  2.0
# 21  2  3.0  1.0
# 22  2  1.0  2.0
# 23  1  NaN  NaN
# 24  2  NaN  NaN
# 25  3  1.0  2.0
# 26  3  1.0  NaN
# 27  3  2.0  NaN
# 28  1  1.0  NaN
# 29  2  NaN  NaN
# 30  3  1.0  NaN
# 31  3  2.0  NaN
# 32  2  3.0  1.0
# 33  3  1.0  NaN
# DataFrame saved to medium sized samples\order_quantities_9.csv
#
# === Dataset 10 (seed=1000) ===
#   n_orders=33, n_itemtypes=7, n_totes=19
# medium sized samples\order_itemtypes_10.csv
#     0    1    2
# 0   0  3.0  NaN
# 1   1  5.0  NaN
# 2   5  3.0  NaN
# 3   2  1.0  3.0
# 4   3  1.0  5.0
# 5   1  0.0  3.0
# 6   5  NaN  NaN
# 7   2  NaN  NaN
# 8   0  5.0  NaN
# 9   2  5.0  0.0
# 10  5  1.0  NaN
# 11  3  0.0  2.0
# 12  4  2.0  NaN
# 13  0  NaN  NaN
# 14  5  0.0  NaN
# 15  2  NaN  NaN
# 16  1  NaN  NaN
# 17  4  2.0  5.0
# 18  5  1.0  NaN
# 19  1  NaN  NaN
# 20  3  2.0  NaN
# 21  5  1.0  0.0
# 22  3  5.0  NaN
# 23  0  5.0  NaN
# 24  2  NaN  NaN
# 25  0  NaN  NaN
# 26  4  NaN  NaN
# 27  4  NaN  NaN
# 28  5  NaN  NaN
# 29  0  1.0  4.0
# 30  0  NaN  NaN
# 31  5  1.0  NaN
# 32  0  4.0  5.0
# DataFrame saved to medium sized samples\order_itemtypes_10.csv
# medium sized samples\orders_totes_10.csv
#      0     1     2
# 0   16   7.0   NaN
# 1   15  15.0   NaN
# 2    8   0.0   NaN
# 3    1   1.0   2.0
# 4   15   6.0  15.0
# 5   13  13.0   6.0
# 6   10   NaN   NaN
# 7    7   NaN   NaN
# 8   10  10.0   NaN
# 9    0   0.0   0.0
# 10   1  15.0   NaN
# 11   4   4.0  13.0
# 12   6   6.0   NaN
# 13  10   NaN   NaN
# 14   3  10.0   NaN
# 15  12   NaN   NaN
# 16  10   NaN   NaN
# 17  15   6.0  15.0
# 18   4  13.0   NaN
# 19   9   NaN   NaN
# 20   3   4.0   NaN
# 21  14   5.0   7.0
# 22   8  17.0   NaN
# 23   2  17.0   NaN
# 24  16   NaN   NaN
# 25   2   NaN   NaN
# 26   5   NaN   NaN
# 27   4   NaN   NaN
# 28  15   NaN   NaN
# 29  14  14.0  14.0
# 30   4   NaN   NaN
# 31  13   0.0   NaN
# 32   9   9.0   9.0
# DataFrame saved to medium sized samples\orders_totes_10.csv
# medium sized samples\order_quantities_10.csv
#     0    1    2
# 0   1  3.0  NaN
# 1   3  1.0  NaN
# 2   1  3.0  NaN
# 3   1  1.0  3.0
# 4   3  3.0  2.0
# 5   3  1.0  3.0
# 6   3  NaN  NaN
# 7   1  NaN  NaN
# 8   2  1.0  NaN
# 9   1  2.0  2.0
# 10  1  2.0  NaN
# 11  2  2.0  2.0
# 12  2  2.0  NaN
# 13  1  NaN  NaN
# 14  1  2.0  NaN
# 15  1  NaN  NaN
# 16  3  NaN  NaN
# 17  2  2.0  3.0
# 18  2  1.0  NaN
# 19  2  NaN  NaN
# 20  1  3.0  NaN
# 21  2  2.0  3.0
# 22  3  1.0  NaN
# 23  1  1.0  NaN
# 24  1  NaN  NaN
# 25  1  NaN  NaN
# 26  2  NaN  NaN
# 27  2  NaN  NaN
# 28  1  NaN  NaN
# 29  3  2.0  3.0
# 30  2  NaN  NaN
# 31  1  2.0  NaN
# 32  1  1.0  3.0
# DataFrame saved to medium sized samples\order_quantities_10.csv
#
# === Dataset 11 (seed=1100) ===
#   n_orders=30, n_itemtypes=7, n_totes=20
# medium sized samples\order_itemtypes_11.csv
#     0    1    2
# 0   0  NaN  NaN
# 1   4  NaN  NaN
# 2   4  NaN  NaN
# 3   4  3.0  0.0
# 4   0  2.0  3.0
# 5   2  NaN  NaN
# 6   3  NaN  NaN
# 7   4  5.0  NaN
# 8   4  NaN  NaN
# 9   4  0.0  2.0
# 10  3  NaN  NaN
# 11  2  1.0  5.0
# 12  2  NaN  NaN
# 13  4  NaN  NaN
# 14  4  NaN  NaN
# 15  1  NaN  NaN
# 16  0  NaN  NaN
# 17  2  3.0  0.0
# 18  4  5.0  1.0
# 19  2  1.0  4.0
# 20  2  NaN  NaN
# 21  2  3.0  4.0
# 22  0  NaN  NaN
# 23  2  3.0  0.0
# 24  4  3.0  1.0
# 25  4  3.0  1.0
# 26  3  1.0  NaN
# 27  4  1.0  NaN
# 28  4  2.0  NaN
# 29  2  1.0  NaN
# DataFrame saved to medium sized samples\order_itemtypes_11.csv
# medium sized samples\orders_totes_11.csv
#      0     1     2
# 0    7   NaN   NaN
# 1   19   NaN   NaN
# 2    2   NaN   NaN
# 3    1   9.0  17.0
# 4    7   5.0   7.0
# 5    4   NaN   NaN
# 6    8   NaN   NaN
# 7    7  16.0   NaN
# 8    7   NaN   NaN
# 9   16   4.0   1.0
# 10  10   NaN   NaN
# 11   8   8.0   8.0
# 12  10   NaN   NaN
# 13  17   NaN   NaN
# 14   2   NaN   NaN
# 15  16   NaN   NaN
# 16  16   NaN   NaN
# 17  11  11.0  11.0
# 18  15  15.0  17.0
# 19   6   6.0  13.0
# 20   2   NaN   NaN
# 21  19   5.0  14.0
# 22   1   NaN   NaN
# 23   3   3.0   3.0
# 24  14  14.0  14.0
# 25   2  18.0   2.0
# 26  16  16.0   NaN
# 27   3   9.0   NaN
# 28  17  16.0   NaN
# 29   2   4.0   NaN
# DataFrame saved to medium sized samples\orders_totes_11.csv
# medium sized samples\order_quantities_11.csv
#     0    1    2
# 0   2  NaN  NaN
# 1   1  NaN  NaN
# 2   1  NaN  NaN
# 3   2  3.0  1.0
# 4   2  2.0  2.0
# 5   1  NaN  NaN
# 6   3  NaN  NaN
# 7   3  2.0  NaN
# 8   1  NaN  NaN
# 9   2  1.0  1.0
# 10  2  NaN  NaN
# 11  1  1.0  2.0
# 12  2  NaN  NaN
# 13  3  NaN  NaN
# 14  3  NaN  NaN
# 15  3  NaN  NaN
# 16  2  NaN  NaN
# 17  1  1.0  2.0
# 18  3  3.0  2.0
# 19  3  2.0  1.0
# 20  1  NaN  NaN
# 21  3  2.0  3.0
# 22  3  NaN  NaN
# 23  2  1.0  1.0
# 24  3  1.0  2.0
# 25  1  2.0  1.0
# 26  1  2.0  NaN
# 27  2  1.0  NaN
# 28  3  2.0  NaN
# 29  2  1.0  NaN
# DataFrame saved to medium sized samples\order_quantities_11.csv
#
# === Dataset 12 (seed=1200) ===
#   n_orders=32, n_itemtypes=8, n_totes=16
# medium sized samples\order_itemtypes_12.csv
#     0    1    2
# 0   5  0.0  1.0
# 1   3  1.0  NaN
# 2   1  3.0  0.0
# 3   1  0.0  3.0
# 4   5  1.0  NaN
# 5   6  2.0  1.0
# 6   0  4.0  NaN
# 7   3  NaN  NaN
# 8   6  1.0  NaN
# 9   1  3.0  0.0
# 10  0  5.0  NaN
# 11  2  NaN  NaN
# 12  3  5.0  NaN
# 13  4  NaN  NaN
# 14  0  3.0  NaN
# 15  1  NaN  NaN
# 16  4  6.0  0.0
# 17  4  5.0  1.0
# 18  0  NaN  NaN
# 19  3  NaN  NaN
# 20  3  4.0  0.0
# 21  6  NaN  NaN
# 22  0  NaN  NaN
# 23  0  NaN  NaN
# 24  0  6.0  3.0
# 25  4  0.0  5.0
# 26  1  NaN  NaN
# 27  4  5.0  NaN
# 28  0  2.0  NaN
# 29  5  2.0  6.0
# 30  6  2.0  3.0
# 31  0  2.0  NaN
# DataFrame saved to medium sized samples\order_itemtypes_12.csv
# medium sized samples\orders_totes_12.csv
#      0     1     2
# 0   13  13.0   4.0
# 1    7   7.0   NaN
# 2   13  13.0   5.0
# 3    2   0.0   2.0
# 4    7   7.0   NaN
# 5    7   7.0  14.0
# 6    0  10.0   NaN
# 7    6   NaN   NaN
# 8   13   4.0   NaN
# 9    5   6.0   7.0
# 10   9   9.0   NaN
# 11   6   NaN   NaN
# 12  14   2.0   NaN
# 13  14   NaN   NaN
# 14   8  10.0   NaN
# 15  14   NaN   NaN
# 16  15   5.0   9.0
# 17   7   7.0  10.0
# 18  14   NaN   NaN
# 19   9   NaN   NaN
# 20  14   5.0  14.0
# 21   5   NaN   NaN
# 22   5   NaN   NaN
# 23   6   NaN   NaN
# 24   7   7.0  10.0
# 25  13  13.0  13.0
# 26   7   NaN   NaN
# 27   5   5.0   NaN
# 28   0   0.0   NaN
# 29  11   5.0   3.0
# 30   9   9.0  10.0
# 31   1   4.0   NaN
# DataFrame saved to medium sized samples\orders_totes_12.csv
# medium sized samples\order_quantities_12.csv
#     0    1    2
# 0   3  2.0  1.0
# 1   1  3.0  NaN
# 2   2  3.0  2.0
# 3   3  1.0  1.0
# 4   1  1.0  NaN
# 5   1  2.0  1.0
# 6   1  3.0  NaN
# 7   3  NaN  NaN
# 8   2  1.0  NaN
# 9   2  1.0  2.0
# 10  3  2.0  NaN
# 11  2  NaN  NaN
# 12  3  2.0  NaN
# 13  3  NaN  NaN
# 14  1  2.0  NaN
# 15  2  NaN  NaN
# 16  2  3.0  1.0
# 17  3  3.0  3.0
# 18  1  NaN  NaN
# 19  1  NaN  NaN
# 20  1  3.0  1.0
# 21  2  NaN  NaN
# 22  3  NaN  NaN
# 23  3  NaN  NaN
# 24  1  1.0  3.0
# 25  2  3.0  3.0
# 26  2  NaN  NaN
# 27  2  1.0  NaN
# 28  3  3.0  NaN
# 29  2  3.0  1.0
# 30  2  1.0  1.0
# 31  3  1.0  NaN
# DataFrame saved to medium sized samples\order_quantities_12.csv
#
# === Dataset 13 (seed=1300) ===
#   n_orders=32, n_itemtypes=8, n_totes=19
# medium sized samples\order_itemtypes_13.csv
#     0    1    2
# 0   5  NaN  NaN
# 1   6  NaN  NaN
# 2   0  4.0  NaN
# 3   5  6.0  1.0
# 4   6  1.0  NaN
# 5   0  2.0  NaN
# 6   0  NaN  NaN
# 7   4  1.0  NaN
# 8   0  6.0  NaN
# 9   0  NaN  NaN
# 10  3  5.0  NaN
# 11  2  NaN  NaN
# 12  3  0.0  1.0
# 13  2  4.0  NaN
# 14  6  1.0  5.0
# 15  2  5.0  NaN
# 16  6  0.0  2.0
# 17  2  NaN  NaN
# 18  6  1.0  NaN
# 19  2  NaN  NaN
# 20  5  1.0  2.0
# 21  2  4.0  1.0
# 22  6  2.0  4.0
# 23  3  4.0  NaN
# 24  4  1.0  NaN
# 25  5  4.0  2.0
# 26  0  5.0  4.0
# 27  5  1.0  NaN
# 28  1  NaN  NaN
# 29  1  3.0  5.0
# 30  1  5.0  NaN
# 31  1  3.0  4.0
# DataFrame saved to medium sized samples\order_itemtypes_13.csv
# medium sized samples\orders_totes_13.csv
#      0     1     2
# 0   11   NaN   NaN
# 1    4   NaN   NaN
# 2   16   5.0   NaN
# 3   11   7.0  11.0
# 4    1  12.0   NaN
# 5   15  15.0   NaN
# 6   14   NaN   NaN
# 7   17  17.0   NaN
# 8    6   6.0   NaN
# 9   18   NaN   NaN
# 10  13  13.0   NaN
# 11  14   NaN   NaN
# 12   7   3.0  16.0
# 13   5   5.0   NaN
# 14   5   7.0   5.0
# 15  13  17.0   NaN
# 16   0  15.0  11.0
# 17   3   NaN   NaN
# 18  15   9.0   NaN
# 19  11   NaN   NaN
# 20  12  10.0  12.0
# 21  18   9.0  18.0
# 22  10  10.0  10.0
# 23   2   2.0   NaN
# 24   3   3.0   NaN
# 25   3   3.0  16.0
# 26   5   5.0  15.0
# 27  18   1.0   NaN
# 28   8   NaN   NaN
# 29  18  15.0  18.0
# 30   2  16.0   NaN
# 31  15  15.0  11.0
# DataFrame saved to medium sized samples\orders_totes_13.csv
# medium sized samples\order_quantities_13.csv
#     0    1    2
# 0   3  NaN  NaN
# 1   2  NaN  NaN
# 2   3  2.0  NaN
# 3   2  3.0  2.0
# 4   2  3.0  NaN
# 5   2  2.0  NaN
# 6   2  NaN  NaN
# 7   3  2.0  NaN
# 8   1  2.0  NaN
# 9   1  NaN  NaN
# 10  1  3.0  NaN
# 11  3  NaN  NaN
# 12  1  3.0  1.0
# 13  3  3.0  NaN
# 14  2  2.0  1.0
# 15  2  2.0  NaN
# 16  2  2.0  3.0
# 17  3  NaN  NaN
# 18  1  2.0  NaN
# 19  3  NaN  NaN
# 20  3  2.0  1.0
# 21  3  1.0  2.0
# 22  3  2.0  3.0
# 23  3  1.0  NaN
# 24  3  2.0  NaN
# 25  3  2.0  1.0
# 26  1  1.0  2.0
# 27  1  1.0  NaN
# 28  3  NaN  NaN
# 29  1  2.0  1.0
# 30  1  3.0  NaN
# 31  3  3.0  1.0
# DataFrame saved to medium sized samples\order_quantities_13.csv
#
# === Dataset 14 (seed=1400) ===
#   n_orders=31, n_itemtypes=8, n_totes=18
# medium sized samples\order_itemtypes_14.csv
#     0    1    2
# 0   4  NaN  NaN
# 1   5  3.0  6.0
# 2   5  1.0  NaN
# 3   3  NaN  NaN
# 4   0  NaN  NaN
# 5   3  NaN  NaN
# 6   1  6.0  0.0
# 7   2  6.0  0.0
# 8   3  6.0  NaN
# 9   0  NaN  NaN
# 10  3  6.0  NaN
# 11  6  NaN  NaN
# 12  2  NaN  NaN
# 13  4  NaN  NaN
# 14  4  5.0  NaN
# 15  6  4.0  2.0
# 16  6  3.0  1.0
# 17  1  4.0  NaN
# 18  6  NaN  NaN
# 19  2  5.0  NaN
# 20  3  1.0  NaN
# 21  4  6.0  0.0
# 22  0  2.0  5.0
# 23  1  NaN  NaN
# 24  3  2.0  4.0
# 25  3  5.0  0.0
# 26  5  3.0  NaN
# 27  2  NaN  NaN
# 28  6  3.0  NaN
# 29  4  1.0  5.0
# 30  1  2.0  NaN
# DataFrame saved to medium sized samples\order_itemtypes_14.csv
# medium sized samples\orders_totes_14.csv
#      0     1     2
# 0    2   NaN   NaN
# 1   16  16.0  16.0
# 2   16   2.0   NaN
# 3   16   NaN   NaN
# 4   13   NaN   NaN
# 5   13   NaN   NaN
# 6    4   4.0  16.0
# 7    7   7.0   7.0
# 8    4   4.0   NaN
# 9    4   NaN   NaN
# 10  15   9.0   NaN
# 11   9   NaN   NaN
# 12  13   NaN   NaN
# 13   1   NaN   NaN
# 14  15  15.0   NaN
# 15   0   4.0   0.0
# 16   9   9.0   4.0
# 17   9  14.0   NaN
# 18  11   NaN   NaN
# 19   4   4.0   NaN
# 20  16  16.0   NaN
# 21  14   9.0  14.0
# 22  17   6.0  17.0
# 23   2   NaN   NaN
# 24   5   3.0   5.0
# 25   2   2.0  16.0
# 26  14  14.0   NaN
# 27   6   NaN   NaN
# 28  13  13.0   NaN
# 29  10   7.0  10.0
# 30  14  14.0   NaN
# DataFrame saved to medium sized samples\orders_totes_14.csv
# medium sized samples\order_quantities_14.csv
#     0    1    2
# 0   3  NaN  NaN
# 1   3  3.0  1.0
# 2   3  3.0  NaN
# 3   2  NaN  NaN
# 4   1  NaN  NaN
# 5   2  NaN  NaN
# 6   3  3.0  3.0
# 7   3  2.0  2.0
# 8   3  3.0  NaN
# 9   2  NaN  NaN
# 10  3  1.0  NaN
# 11  3  NaN  NaN
# 12  3  NaN  NaN
# 13  2  NaN  NaN
# 14  2  3.0  NaN
# 15  3  3.0  3.0
# 16  3  3.0  3.0
# 17  1  1.0  NaN
# 18  2  NaN  NaN
# 19  2  3.0  NaN
# 20  1  3.0  NaN
# 21  2  2.0  2.0
# 22  2  2.0  2.0
# 23  1  NaN  NaN
# 24  1  2.0  3.0
# 25  1  3.0  2.0
# 26  1  3.0  NaN
# 27  2  NaN  NaN
# 28  2  1.0  NaN
# 29  2  3.0  1.0
# 30  3  3.0  NaN
# DataFrame saved to medium sized samples\order_quantities_14.csv
#
# === Dataset 15 (seed=1500) ===
#   n_orders=32, n_itemtypes=7, n_totes=19
# medium sized samples\order_itemtypes_15.csv
#     0    1    2
# 0   0  2.0  NaN
# 1   1  5.0  0.0
# 2   0  5.0  NaN
# 3   1  3.0  NaN
# 4   2  NaN  NaN
# 5   2  3.0  5.0
# 6   1  NaN  NaN
# 7   4  NaN  NaN
# 8   2  5.0  NaN
# 9   2  1.0  0.0
# 10  1  2.0  4.0
# 11  1  0.0  NaN
# 12  2  NaN  NaN
# 13  3  0.0  NaN
# 14  3  NaN  NaN
# 15  3  1.0  NaN
# 16  4  1.0  3.0
# 17  4  1.0  NaN
# 18  1  3.0  NaN
# 19  2  0.0  NaN
# 20  5  2.0  NaN
# 21  1  3.0  NaN
# 22  5  4.0  1.0
# 23  4  0.0  NaN
# 24  5  NaN  NaN
# 25  3  NaN  NaN
# 26  3  4.0  5.0
# 27  4  NaN  NaN
# 28  3  4.0  0.0
# 29  1  NaN  NaN
# 30  4  0.0  1.0
# 31  2  NaN  NaN
# DataFrame saved to medium sized samples\order_itemtypes_15.csv
# medium sized samples\orders_totes_15.csv
#      0     1     2
# 0   14  14.0   NaN
# 1   10   8.0  10.0
# 2   10   4.0   NaN
# 3   13   5.0   NaN
# 4    6   NaN   NaN
# 5    6   6.0   9.0
# 6    1   NaN   NaN
# 7    1   NaN   NaN
# 8    3  16.0   NaN
# 9    7  15.0   6.0
# 10   7   3.0   7.0
# 11  15  16.0   NaN
# 12  17   NaN   NaN
# 13  13  10.0   NaN
# 14  14   NaN   NaN
# 15  11  11.0   NaN
# 16   2  14.0   2.0
# 17  15  15.0   NaN
# 18  13  13.0   NaN
# 19   3   3.0   NaN
# 20  15  15.0   NaN
# 21  10  10.0   NaN
# 22  17  15.0  10.0
# 23   7   7.0   NaN
# 24   1   NaN   NaN
# 25  10   NaN   NaN
# 26   2   2.0   7.0
# 27   0   NaN   NaN
# 28   0  10.0  14.0
# 29   9   NaN   NaN
# 30   4   4.0   4.0
# 31   5   NaN   NaN
# DataFrame saved to medium sized samples\orders_totes_15.csv
# medium sized samples\order_quantities_15.csv
#     0    1    2
# 0   2  2.0  NaN
# 1   2  1.0  1.0
# 2   2  3.0  NaN
# 3   3  3.0  NaN
# 4   3  NaN  NaN
# 5   1  2.0  2.0
# 6   1  NaN  NaN
# 7   2  NaN  NaN
# 8   2  1.0  NaN
# 9   1  2.0  1.0
# 10  2  1.0  3.0
# 11  3  1.0  NaN
# 12  3  NaN  NaN
# 13  3  2.0  NaN
# 14  3  NaN  NaN
# 15  3  3.0  NaN
# 16  1  3.0  2.0
# 17  1  2.0  NaN
# 18  3  2.0  NaN
# 19  2  3.0  NaN
# 20  1  2.0  NaN
# 21  2  1.0  NaN
# 22  3  2.0  2.0
# 23  1  3.0  NaN
# 24  1  NaN  NaN
# 25  1  NaN  NaN
# 26  1  1.0  3.0
# 27  2  NaN  NaN
# 28  2  3.0  3.0
# 29  1  NaN  NaN
# 30  2  3.0  1.0
# 31  1  NaN  NaN
# DataFrame saved to medium sized samples\order_quantities_15.csv
#
# === Dataset 16 (seed=1600) ===
#   n_orders=30, n_itemtypes=8, n_totes=20
# medium sized samples\order_itemtypes_16.csv
#     0    1    2
# 0   5  NaN  NaN
# 1   5  4.0  3.0
# 2   4  NaN  NaN
# 3   2  6.0  NaN
# 4   2  NaN  NaN
# 5   3  2.0  5.0
# 6   4  1.0  NaN
# 7   0  6.0  3.0
# 8   0  NaN  NaN
# 9   5  1.0  3.0
# 10  5  NaN  NaN
# 11  4  2.0  0.0
# 12  3  4.0  6.0
# 13  4  NaN  NaN
# 14  2  4.0  NaN
# 15  3  5.0  4.0
# 16  3  5.0  NaN
# 17  6  4.0  2.0
# 18  6  3.0  NaN
# 19  1  3.0  NaN
# 20  3  4.0  NaN
# 21  5  4.0  3.0
# 22  0  2.0  4.0
# 23  5  3.0  NaN
# 24  1  4.0  NaN
# 25  1  NaN  NaN
# 26  0  NaN  NaN
# 27  3  NaN  NaN
# 28  0  6.0  2.0
# 29  2  4.0  0.0
# DataFrame saved to medium sized samples\order_itemtypes_16.csv
# medium sized samples\orders_totes_16.csv
#      0     1     2
# 0    3   NaN   NaN
# 1    4   4.0   4.0
# 2   13   NaN   NaN
# 3    7   7.0   NaN
# 4    9   NaN   NaN
# 5    7   5.0   7.0
# 6   12   2.0   NaN
# 7   10  10.0  14.0
# 8    5   NaN   NaN
# 9    1  19.0   1.0
# 10   6   NaN   NaN
# 11   0   3.0   0.0
# 12  13  13.0   8.0
# 13   6   NaN   NaN
# 14   8   8.0   NaN
# 15   1   1.0   1.0
# 16   5   5.0   NaN
# 17   1   1.0   1.0
# 18  19  18.0   NaN
# 19   3   3.0   NaN
# 20  17  17.0   NaN
# 21  14  16.0  14.0
# 22   0   0.0   0.0
# 23   8   8.0   NaN
# 24  12  12.0   NaN
# 25  18   NaN   NaN
# 26   8   NaN   NaN
# 27   0   NaN   NaN
# 28  14  14.0   3.0
# 29  11  11.0  11.0
# DataFrame saved to medium sized samples\orders_totes_16.csv
# medium sized samples\order_quantities_16.csv
#     0    1    2
# 0   2  NaN  NaN
# 1   2  1.0  1.0
# 2   2  NaN  NaN
# 3   1  1.0  NaN
# 4   2  NaN  NaN
# 5   2  1.0  2.0
# 6   1  1.0  NaN
# 7   3  2.0  3.0
# 8   2  NaN  NaN
# 9   1  3.0  3.0
# 10  1  NaN  NaN
# 11  3  2.0  2.0
# 12  3  1.0  1.0
# 13  3  NaN  NaN
# 14  3  1.0  NaN
# 15  3  2.0  1.0
# 16  2  1.0  NaN
# 17  2  2.0  1.0
# 18  1  2.0  NaN
# 19  1  3.0  NaN
# 20  1  1.0  NaN
# 21  2  2.0  3.0
# 22  2  3.0  3.0
# 23  2  1.0  NaN
# 24  3  3.0  NaN
# 25  1  NaN  NaN
# 26  2  NaN  NaN
# 27  2  NaN  NaN
# 28  1  2.0  1.0
# 29  3  1.0  2.0
# DataFrame saved to medium sized samples\order_quantities_16.csv
#
# === Dataset 17 (seed=1700) ===
#   n_orders=33, n_itemtypes=7, n_totes=19
# medium sized samples\order_itemtypes_17.csv
#     0    1    2
# 0   5  1.0  NaN
# 1   4  3.0  NaN
# 2   2  NaN  NaN
# 3   3  4.0  NaN
# 4   0  1.0  4.0
# 5   5  1.0  NaN
# 6   4  NaN  NaN
# 7   5  NaN  NaN
# 8   2  NaN  NaN
# 9   2  NaN  NaN
# 10  0  NaN  NaN
# 11  1  NaN  NaN
# 12  0  NaN  NaN
# 13  3  0.0  2.0
# 14  3  5.0  NaN
# 15  2  4.0  3.0
# 16  4  2.0  1.0
# 17  2  NaN  NaN
# 18  3  1.0  4.0
# 19  3  0.0  NaN
# 20  1  2.0  4.0
# 21  5  4.0  NaN
# 22  3  4.0  5.0
# 23  4  NaN  NaN
# 24  5  NaN  NaN
# 25  5  NaN  NaN
# 26  3  NaN  NaN
# 27  5  0.0  NaN
# 28  2  NaN  NaN
# 29  4  NaN  NaN
# 30  5  3.0  NaN
# 31  1  2.0  NaN
# 32  0  NaN  NaN
# DataFrame saved to medium sized samples\order_itemtypes_17.csv
# medium sized samples\orders_totes_17.csv
#      0     1     2
# 0   12  11.0   NaN
# 1   18  18.0   NaN
# 2   10   NaN   NaN
# 3    1   1.0   NaN
# 4   10  10.0   0.0
# 5   14  10.0   NaN
# 6    5   NaN   NaN
# 7    1   NaN   NaN
# 8   18   NaN   NaN
# 9   16   NaN   NaN
# 10   5   NaN   NaN
# 11  12   NaN   NaN
# 12   5   NaN   NaN
# 13  14   4.0  14.0
# 14  14  14.0   NaN
# 15  15  15.0   0.0
# 16  15  13.0  11.0
# 17  17   NaN   NaN
# 18  12  12.0  12.0
# 19  17   7.0   NaN
# 20  10  10.0  10.0
# 21   8   8.0   NaN
# 22  10  10.0  10.0
# 23   0   NaN   NaN
# 24   9   NaN   NaN
# 25   7   NaN   NaN
# 26   0   NaN   NaN
# 27   5  15.0   NaN
# 28   6   NaN   NaN
# 29  17   NaN   NaN
# 30   0   0.0   NaN
# 31  11  11.0   NaN
# 32   4   NaN   NaN
# DataFrame saved to medium sized samples\orders_totes_17.csv
# medium sized samples\order_quantities_17.csv
#     0    1    2
# 0   1  1.0  NaN
# 1   3  3.0  NaN
# 2   1  NaN  NaN
# 3   3  2.0  NaN
# 4   3  3.0  2.0
# 5   1  2.0  NaN
# 6   1  NaN  NaN
# 7   1  NaN  NaN
# 8   3  NaN  NaN
# 9   3  NaN  NaN
# 10  2  NaN  NaN
# 11  2  NaN  NaN
# 12  1  NaN  NaN
# 13  2  2.0  1.0
# 14  2  3.0  NaN
# 15  2  2.0  1.0
# 16  1  1.0  1.0
# 17  3  NaN  NaN
# 18  3  1.0  1.0
# 19  2  3.0  NaN
# 20  2  3.0  2.0
# 21  3  1.0  NaN
# 22  3  1.0  3.0
# 23  2  NaN  NaN
# 24  3  NaN  NaN
# 25  3  NaN  NaN
# 26  3  NaN  NaN
# 27  1  3.0  NaN
# 28  3  NaN  NaN
# 29  1  NaN  NaN
# 30  3  3.0  NaN
# 31  3  2.0  NaN
# 32  3  NaN  NaN
# DataFrame saved to medium sized samples\order_quantities_17.csv
#
# === Dataset 18 (seed=1800) ===
#   n_orders=32, n_itemtypes=7, n_totes=17
# medium sized samples\order_itemtypes_18.csv
#     0    1    2
# 0   2  4.0  NaN
# 1   1  5.0  NaN
# 2   5  NaN  NaN
# 3   1  0.0  NaN
# 4   0  2.0  NaN
# 5   1  0.0  4.0
# 6   1  5.0  2.0
# 7   3  1.0  2.0
# 8   1  5.0  4.0
# 9   2  5.0  NaN
# 10  3  0.0  NaN
# 11  2  NaN  NaN
# 12  0  2.0  5.0
# 13  4  5.0  1.0
# 14  4  0.0  1.0
# 15  3  NaN  NaN
# 16  4  3.0  NaN
# 17  0  NaN  NaN
# 18  5  2.0  4.0
# 19  4  NaN  NaN
# 20  3  1.0  NaN
# 21  2  4.0  1.0
# 22  2  NaN  NaN
# 23  4  NaN  NaN
# 24  3  2.0  NaN
# 25  2  NaN  NaN
# 26  5  2.0  4.0
# 27  5  2.0  NaN
# 28  0  5.0  4.0
# 29  1  4.0  3.0
# 30  2  4.0  NaN
# 31  2  NaN  NaN
# DataFrame saved to medium sized samples\order_itemtypes_18.csv
# medium sized samples\orders_totes_18.csv
#      0     1     2
# 0    4   4.0   NaN
# 1    0  14.0   NaN
# 2    3   NaN   NaN
# 3   11  11.0   NaN
# 4   10  14.0   NaN
# 5    6   6.0   6.0
# 6    2   2.0   2.0
# 7   10   1.0  13.0
# 8   12   5.0  15.0
# 9    0   0.0   NaN
# 10  12   0.0   NaN
# 11   9   NaN   NaN
# 12   2   8.0   2.0
# 13   3   3.0   7.0
# 14   1  12.0  14.0
# 15   8   NaN   NaN
# 16  14   9.0   NaN
# 17   0   NaN   NaN
# 18   2   2.0   2.0
# 19   5   NaN   NaN
# 20   6   3.0   NaN
# 21  16  16.0  16.0
# 22   8   NaN   NaN
# 23  16   NaN   NaN
# 24   2  16.0   NaN
# 25  11   NaN   NaN
# 26   9   2.0   9.0
# 27   1   1.0   NaN
# 28   0   0.0   0.0
# 29   8  11.0   8.0
# 30   8   8.0   NaN
# 31   7   NaN   NaN
# DataFrame saved to medium sized samples\orders_totes_18.csv
# medium sized samples\order_quantities_18.csv
#     0    1    2
# 0   2  3.0  NaN
# 1   3  2.0  NaN
# 2   3  NaN  NaN
# 3   2  3.0  NaN
# 4   1  2.0  NaN
# 5   2  3.0  1.0
# 6   1  3.0  3.0
# 7   1  1.0  2.0
# 8   1  2.0  2.0
# 9   1  2.0  NaN
# 10  3  2.0  NaN
# 11  2  NaN  NaN
# 12  3  2.0  2.0
# 13  2  3.0  3.0
# 14  3  1.0  2.0
# 15  1  NaN  NaN
# 16  1  2.0  NaN
# 17  3  NaN  NaN
# 18  1  2.0  1.0
# 19  1  NaN  NaN
# 20  1  2.0  NaN
# 21  2  3.0  3.0
# 22  3  NaN  NaN
# 23  1  NaN  NaN
# 24  2  3.0  NaN
# 25  1  NaN  NaN
# 26  3  1.0  3.0
# 27  3  1.0  NaN
# 28  3  2.0  2.0
# 29  3  3.0  2.0
# 30  2  2.0  NaN
# 31  3  NaN  NaN
# DataFrame saved to medium sized samples\order_quantities_18.csv
#
# === Dataset 19 (seed=1900) ===
#   n_orders=30, n_itemtypes=8, n_totes=17
# medium sized samples\order_itemtypes_19.csv
#     0    1    2
# 0   1  6.0  0.0
# 1   4  0.0  2.0
# 2   0  4.0  NaN
# 3   3  6.0  NaN
# 4   2  0.0  NaN
# 5   0  4.0  NaN
# 6   1  5.0  3.0
# 7   4  1.0  NaN
# 8   0  1.0  NaN
# 9   5  6.0  3.0
# 10  1  4.0  5.0
# 11  4  NaN  NaN
# 12  0  5.0  NaN
# 13  5  NaN  NaN
# 14  4  0.0  2.0
# 15  4  NaN  NaN
# 16  3  NaN  NaN
# 17  3  NaN  NaN
# 18  5  2.0  NaN
# 19  3  4.0  NaN
# 20  2  3.0  5.0
# 21  2  3.0  NaN
# 22  0  1.0  5.0
# 23  5  4.0  6.0
# 24  3  NaN  NaN
# 25  1  NaN  NaN
# 26  4  0.0  3.0
# 27  2  0.0  3.0
# 28  3  1.0  0.0
# 29  6  2.0  NaN
# DataFrame saved to medium sized samples\order_itemtypes_19.csv
# medium sized samples\orders_totes_19.csv
#      0     1     2
# 0    3   9.0   3.0
# 1   15  15.0  15.0
# 2   12  12.0   NaN
# 3    9   8.0   NaN
# 4    9   9.0   NaN
# 5    8   8.0   NaN
# 6   12  12.0  12.0
# 7    3   3.0   NaN
# 8    7  13.0   NaN
# 9    8   4.0   8.0
# 10   4   4.0   4.0
# 11  12   NaN   NaN
# 12   1  10.0   NaN
# 13  11   NaN   NaN
# 14   0   0.0   0.0
# 15   7   NaN   NaN
# 16  15   NaN   NaN
# 17  12   NaN   NaN
# 18   6   6.0   NaN
# 19  10  10.0   NaN
# 20   4  14.0  12.0
# 21   2   0.0   NaN
# 22   2   2.0   2.0
# 23   4   4.0   0.0
# 24   3   NaN   NaN
# 25   3   NaN   NaN
# 26   6   5.0   6.0
# 27   4   0.0   9.0
# 28   1   0.0   7.0
# 29   2   2.0   NaN
# DataFrame saved to medium sized samples\orders_totes_19.csv
# medium sized samples\order_quantities_19.csv
#     0    1    2
# 0   2  3.0  2.0
# 1   3  2.0  2.0
# 2   3  3.0  NaN
# 3   2  3.0  NaN
# 4   3  1.0  NaN
# 5   3  3.0  NaN
# 6   3  1.0  1.0
# 7   2  3.0  NaN
# 8   1  2.0  NaN
# 9   2  1.0  2.0
# 10  1  1.0  3.0
# 11  1  NaN  NaN
# 12  2  2.0  NaN
# 13  1  NaN  NaN
# 14  3  2.0  3.0
# 15  2  NaN  NaN
# 16  1  NaN  NaN
# 17  2  NaN  NaN
# 18  2  3.0  NaN
# 19  2  2.0  NaN
# 20  3  2.0  1.0
# 21  2  3.0  NaN
# 22  2  1.0  3.0
# 23  3  2.0  2.0
# 24  1  NaN  NaN
# 25  1  NaN  NaN
# 26  1  3.0  2.0
# 27  3  3.0  1.0
# 28  1  2.0  3.0
# 29  2  3.0  NaN
# DataFrame saved to medium sized samples\order_quantities_19.csv
#
# === Dataset 20 (seed=2000) ===
#   n_orders=33, n_itemtypes=7, n_totes=19
# medium sized samples\order_itemtypes_20.csv
#     0    1    2
# 0   5  1.0  NaN
# 1   3  NaN  NaN
# 2   1  4.0  2.0
# 3   1  NaN  NaN
# 4   4  NaN  NaN
# 5   5  3.0  1.0
# 6   5  NaN  NaN
# 7   0  4.0  1.0
# 8   3  0.0  NaN
# 9   1  NaN  NaN
# 10  4  0.0  NaN
# 11  5  NaN  NaN
# 12  4  0.0  5.0
# 13  3  1.0  4.0
# 14  0  NaN  NaN
# 15  1  2.0  5.0
# 16  4  5.0  1.0
# 17  2  0.0  NaN
# 18  3  NaN  NaN
# 19  4  3.0  NaN
# 20  5  NaN  NaN
# 21  1  NaN  NaN
# 22  3  1.0  2.0
# 23  3  5.0  1.0
# 24  4  NaN  NaN
# 25  5  2.0  3.0
# 26  2  3.0  NaN
# 27  1  NaN  NaN
# 28  3  NaN  NaN
# 29  2  0.0  3.0
# 30  5  NaN  NaN
# 31  3  2.0  5.0
# 32  2  NaN  NaN
# DataFrame saved to medium sized samples\order_itemtypes_20.csv
# medium sized samples\orders_totes_20.csv
#      0     1     2
# 0    6   7.0   NaN
# 1   12   NaN   NaN
# 2    3   3.0   3.0
# 3   13   NaN   NaN
# 4    0   NaN   NaN
# 5    2  10.0   2.0
# 6   16   NaN   NaN
# 7    0   0.0   0.0
# 8    2   2.0   NaN
# 9    0   NaN   NaN
# 10   7   9.0   NaN
# 11  14   NaN   NaN
# 12  15  15.0  15.0
# 13   7   7.0   7.0
# 14  15   NaN   NaN
# 15  13   3.0  13.0
# 16   2   2.0   2.0
# 17  14  13.0   NaN
# 18  10   NaN   NaN
# 19   3  17.0   NaN
# 20   2   NaN   NaN
# 21   9   NaN   NaN
# 22   9   9.0   9.0
# 23  15   2.0  15.0
# 24  17   NaN   NaN
# 25   2   2.0   6.0
# 26   8   8.0   NaN
# 27  18   NaN   NaN
# 28   7   NaN   NaN
# 29  11  11.0   1.0
# 30  16   NaN   NaN
# 31   4  10.0   4.0
# 32  10   NaN   NaN
# DataFrame saved to medium sized samples\orders_totes_20.csv
# medium sized samples\order_quantities_20.csv
#     0    1    2
# 0   3  3.0  NaN
# 1   1  NaN  NaN
# 2   2  3.0  2.0
# 3   3  NaN  NaN
# 4   3  NaN  NaN
# 5   1  3.0  1.0
# 6   2  NaN  NaN
# 7   3  1.0  2.0
# 8   2  3.0  NaN
# 9   2  NaN  NaN
# 10  1  2.0  NaN
# 11  2  NaN  NaN
# 12  1  1.0  1.0
# 13  1  3.0  1.0
# 14  1  NaN  NaN
# 15  3  3.0  1.0
# 16  1  3.0  1.0
# 17  2  1.0  NaN
# 18  2  NaN  NaN
# 19  3  2.0  NaN
# 20  1  NaN  NaN
# 21  1  NaN  NaN
# 22  2  1.0  3.0
# 23  2  3.0  1.0
# 24  1  NaN  NaN
# 25  1  3.0  2.0
# 26  3  1.0  NaN
# 27  1  NaN  NaN
# 28  3  NaN  NaN
# 29  3  1.0  1.0
# 30  2  NaN  NaN
# 31  2  1.0  1.0
# 32  2  NaN  NaN
# DataFrame saved to medium sized samples\order_quantities_20.csv
#
# === Dataset 21 (seed=2100) ===
#   n_orders=32, n_itemtypes=8, n_totes=16
# medium sized samples\order_itemtypes_21.csv
#     0    1    2
# 0   0  4.0  NaN
# 1   0  6.0  1.0
# 2   0  5.0  NaN
# 3   3  NaN  NaN
# 4   2  6.0  0.0
# 5   6  2.0  NaN
# 6   5  3.0  NaN
# 7   5  3.0  1.0
# 8   0  3.0  NaN
# 9   4  NaN  NaN
# 10  3  6.0  NaN
# 11  1  5.0  NaN
# 12  5  1.0  NaN
# 13  6  NaN  NaN
# 14  0  6.0  4.0
# 15  2  NaN  NaN
# 16  3  5.0  4.0
# 17  2  4.0  NaN
# 18  0  6.0  NaN
# 19  4  NaN  NaN
# 20  0  3.0  4.0
# 21  1  2.0  5.0
# 22  4  NaN  NaN
# 23  5  NaN  NaN
# 24  2  NaN  NaN
# 25  0  NaN  NaN
# 26  3  4.0  NaN
# 27  1  NaN  NaN
# 28  6  NaN  NaN
# 29  0  NaN  NaN
# 30  4  2.0  NaN
# 31  3  2.0  NaN
# DataFrame saved to medium sized samples\order_itemtypes_21.csv
# medium sized samples\orders_totes_21.csv
#      0     1     2
# 0   13  11.0   NaN
# 1    1   1.0   1.0
# 2    4  15.0   NaN
# 3    2   NaN   NaN
# 4    3   4.0   3.0
# 5    8   5.0   NaN
# 6    4   8.0   NaN
# 7    9   9.0   9.0
# 8    0   0.0   NaN
# 9   10   NaN   NaN
# 10   5  15.0   NaN
# 11   9   9.0   NaN
# 12   2   3.0   NaN
# 13   1   NaN   NaN
# 14   5   5.0  12.0
# 15  13   NaN   NaN
# 16   0   0.0   0.0
# 17  11  11.0   NaN
# 18  11  14.0   NaN
# 19   9   NaN   NaN
# 20  10  14.0  14.0
# 21   0  13.0   0.0
# 22   9   NaN   NaN
# 23  14   NaN   NaN
# 24   5   NaN   NaN
# 25   8   NaN   NaN
# 26  14  14.0   NaN
# 27   1   NaN   NaN
# 28  12   NaN   NaN
# 29   1   NaN   NaN
# 30  14   2.0   NaN
# 31   2   2.0   NaN
# DataFrame saved to medium sized samples\orders_totes_21.csv
# medium sized samples\order_quantities_21.csv
#     0    1    2
# 0   2  2.0  NaN
# 1   1  2.0  2.0
# 2   3  2.0  NaN
# 3   2  NaN  NaN
# 4   2  3.0  2.0
# 5   3  2.0  NaN
# 6   2  2.0  NaN
# 7   2  2.0  2.0
# 8   1  3.0  NaN
# 9   2  NaN  NaN
# 10  2  3.0  NaN
# 11  3  2.0  NaN
# 12  1  3.0  NaN
# 13  2  NaN  NaN
# 14  1  1.0  3.0
# 15  3  NaN  NaN
# 16  1  1.0  2.0
# 17  1  2.0  NaN
# 18  2  1.0  NaN
# 19  2  NaN  NaN
# 20  1  3.0  2.0
# 21  1  2.0  1.0
# 22  2  NaN  NaN
# 23  2  NaN  NaN
# 24  1  NaN  NaN
# 25  1  NaN  NaN
# 26  3  3.0  NaN
# 27  1  NaN  NaN
# 28  2  NaN  NaN
# 29  3  NaN  NaN
# 30  1  2.0  NaN
# 31  1  3.0  NaN
# DataFrame saved to medium sized samples\order_quantities_21.csv
#
# === Dataset 22 (seed=2200) ===
#   n_orders=32, n_itemtypes=7, n_totes=19
# medium sized samples\order_itemtypes_22.csv
#     0    1    2
# 0   4  3.0  1.0
# 1   0  2.0  NaN
# 2   3  NaN  NaN
# 3   4  2.0  5.0
# 4   1  5.0  3.0
# 5   2  NaN  NaN
# 6   2  5.0  0.0
# 7   0  1.0  NaN
# 8   4  5.0  1.0
# 9   0  NaN  NaN
# 10  0  1.0  NaN
# 11  0  NaN  NaN
# 12  3  1.0  5.0
# 13  1  5.0  NaN
# 14  4  2.0  5.0
# 15  5  0.0  4.0
# 16  5  2.0  NaN
# 17  2  NaN  NaN
# 18  1  3.0  0.0
# 19  5  3.0  0.0
# 20  2  4.0  NaN
# 21  4  3.0  5.0
# 22  0  1.0  NaN
# 23  3  4.0  1.0
# 24  3  NaN  NaN
# 25  3  NaN  NaN
# 26  3  4.0  NaN
# 27  5  4.0  NaN
# 28  3  0.0  4.0
# 29  1  3.0  NaN
# 30  4  5.0  NaN
# 31  2  1.0  3.0
# DataFrame saved to medium sized samples\order_itemtypes_22.csv
# medium sized samples\orders_totes_22.csv
#      0     1     2
# 0    1  10.0   1.0
# 1   14  14.0   NaN
# 2   18   NaN   NaN
# 3    7   3.0  13.0
# 4   16   6.0   9.0
# 5   18   NaN   NaN
# 6    9   9.0   9.0
# 7    0   0.0   NaN
# 8    4   4.0   4.0
# 9   16   NaN   NaN
# 10  13  16.0   NaN
# 11   3   NaN   NaN
# 12   2   2.0  17.0
# 13   9   6.0   NaN
# 14  18   2.0  14.0
# 15  10  10.0  10.0
# 16  16  16.0   NaN
# 17  18   NaN   NaN
# 18   6   6.0   6.0
# 19   5   5.0   6.0
# 20   6  13.0   NaN
# 21   0   0.0  10.0
# 22   2   2.0   NaN
# 23   9   9.0   9.0
# 24   3   NaN   NaN
# 25  11   NaN   NaN
# 26  14  16.0   NaN
# 27   7   6.0   NaN
# 28   5  16.0   5.0
# 29   8   6.0   NaN
# 30  13   2.0   NaN
# 31   9   9.0  11.0
# DataFrame saved to medium sized samples\orders_totes_22.csv
# medium sized samples\order_quantities_22.csv
#     0    1    2
# 0   1  1.0  2.0
# 1   3  1.0  NaN
# 2   3  NaN  NaN
# 3   1  2.0  3.0
# 4   1  1.0  1.0
# 5   3  NaN  NaN
# 6   2  3.0  2.0
# 7   1  3.0  NaN
# 8   1  1.0  2.0
# 9   2  NaN  NaN
# 10  1  2.0  NaN
# 11  2  NaN  NaN
# 12  1  1.0  3.0
# 13  2  2.0  NaN
# 14  3  3.0  2.0
# 15  2  1.0  3.0
# 16  1  3.0  NaN
# 17  1  NaN  NaN
# 18  2  1.0  3.0
# 19  1  1.0  3.0
# 20  1  3.0  NaN
# 21  1  1.0  2.0
# 22  3  1.0  NaN
# 23  1  2.0  2.0
# 24  2  NaN  NaN
# 25  3  NaN  NaN
# 26  3  3.0  NaN
# 27  3  1.0  NaN
# 28  1  3.0  2.0
# 29  2  1.0  NaN
# 30  3  2.0  NaN
# 31  1  1.0  1.0
# DataFrame saved to medium sized samples\order_quantities_22.csv
#
# === Dataset 23 (seed=2300) ===
#   n_orders=33, n_itemtypes=8, n_totes=18
# medium sized samples\order_itemtypes_23.csv
#     0    1    2
# 0   0  5.0  NaN
# 1   1  NaN  NaN
# 2   2  4.0  1.0
# 3   0  3.0  NaN
# 4   3  NaN  NaN
# 5   3  4.0  5.0
# 6   6  2.0  NaN
# 7   4  NaN  NaN
# 8   2  NaN  NaN
# 9   1  0.0  NaN
# 10  2  NaN  NaN
# 11  2  NaN  NaN
# 12  6  3.0  1.0
# 13  4  NaN  NaN
# 14  6  NaN  NaN
# 15  1  NaN  NaN
# 16  4  2.0  3.0
# 17  6  0.0  NaN
# 18  6  5.0  NaN
# 19  5  3.0  NaN
# 20  2  NaN  NaN
# 21  6  3.0  NaN
# 22  3  NaN  NaN
# 23  4  NaN  NaN
# 24  0  NaN  NaN
# 25  5  1.0  2.0
# 26  2  6.0  NaN
# 27  5  NaN  NaN
# 28  2  0.0  NaN
# 29  3  2.0  NaN
# 30  3  5.0  1.0
# 31  1  3.0  2.0
# 32  3  6.0  NaN
# DataFrame saved to medium sized samples\order_itemtypes_23.csv
# medium sized samples\orders_totes_23.csv
#      0     1     2
# 0    6  15.0   NaN
# 1    4   NaN   NaN
# 2    4   0.0  14.0
# 3   10  10.0   NaN
# 4    0   NaN   NaN
# 5    7   7.0   7.0
# 6    3   3.0   NaN
# 7    6   NaN   NaN
# 8   10   NaN   NaN
# 9   11  11.0   NaN
# 10  12   NaN   NaN
# 11  11   NaN   NaN
# 12   7   7.0   2.0
# 13  13   NaN   NaN
# 14   3   NaN   NaN
# 15  10   NaN   NaN
# 16   3  16.0   4.0
# 17  16  16.0   NaN
# 18  11  13.0   NaN
# 19  14  10.0   NaN
# 20  12   NaN   NaN
# 21   7   3.0   NaN
# 22   6   NaN   NaN
# 23  11   NaN   NaN
# 24  15   NaN   NaN
# 25  17   1.0  17.0
# 26   1   1.0   NaN
# 27   4   NaN   NaN
# 28  15   9.0   NaN
# 29   9   7.0   NaN
# 30   4  13.0   5.0
# 31  13   5.0  11.0
# 32   8   8.0   NaN
# DataFrame saved to medium sized samples\orders_totes_23.csv
# medium sized samples\order_quantities_23.csv
#     0    1    2
# 0   1  1.0  NaN
# 1   1  NaN  NaN
# 2   2  2.0  2.0
# 3   1  2.0  NaN
# 4   3  NaN  NaN
# 5   1  1.0  2.0
# 6   2  3.0  NaN
# 7   3  NaN  NaN
# 8   1  NaN  NaN
# 9   3  3.0  NaN
# 10  3  NaN  NaN
# 11  3  NaN  NaN
# 12  3  3.0  3.0
# 13  1  NaN  NaN
# 14  2  NaN  NaN
# 15  3  NaN  NaN
# 16  1  2.0  1.0
# 17  3  3.0  NaN
# 18  2  3.0  NaN
# 19  1  3.0  NaN
# 20  3  NaN  NaN
# 21  2  3.0  NaN
# 22  3  NaN  NaN
# 23  1  NaN  NaN
# 24  2  NaN  NaN
# 25  2  3.0  3.0
# 26  2  2.0  NaN
# 27  1  NaN  NaN
# 28  1  1.0  NaN
# 29  3  1.0  NaN
# 30  3  1.0  1.0
# 31  2  3.0  3.0
# 32  2  2.0  NaN
# DataFrame saved to medium sized samples\order_quantities_23.csv
#
# === Dataset 24 (seed=2400) ===
#   n_orders=30, n_itemtypes=7, n_totes=19
# medium sized samples\order_itemtypes_24.csv
#     0    1    2
# 0   0  NaN  NaN
# 1   1  0.0  3.0
# 2   1  0.0  5.0
# 3   0  4.0  3.0
# 4   1  NaN  NaN
# 5   1  3.0  2.0
# 6   5  1.0  NaN
# 7   1  0.0  2.0
# 8   1  3.0  2.0
# 9   2  1.0  5.0
# 10  5  1.0  4.0
# 11  2  5.0  4.0
# 12  3  NaN  NaN
# 13  5  4.0  1.0
# 14  2  1.0  0.0
# 15  2  NaN  NaN
# 16  0  NaN  NaN
# 17  2  NaN  NaN
# 18  0  5.0  3.0
# 19  2  NaN  NaN
# 20  1  NaN  NaN
# 21  3  NaN  NaN
# 22  4  1.0  NaN
# 23  3  2.0  5.0
# 24  1  0.0  NaN
# 25  0  NaN  NaN
# 26  0  4.0  3.0
# 27  0  NaN  NaN
# 28  1  NaN  NaN
# 29  3  5.0  NaN
# DataFrame saved to medium sized samples\order_itemtypes_24.csv
# medium sized samples\orders_totes_24.csv
#      0     1     2
# 0   13   NaN   NaN
# 1   18  18.0  12.0
# 2    6   6.0   6.0
# 3    3   3.0   3.0
# 4    7   NaN   NaN
# 5    0   0.0  11.0
# 6    1   5.0   NaN
# 7   13  10.0  13.0
# 8   10   6.0  10.0
# 9    8   1.0   5.0
# 10   0   0.0  15.0
# 11   6   6.0   6.0
# 12  12   NaN   NaN
# 13   0  16.0   9.0
# 14  15  15.0   9.0
# 15  12   NaN   NaN
# 16  10   NaN   NaN
# 17  13   NaN   NaN
# 18  18  18.0  18.0
# 19   1   NaN   NaN
# 20   2   NaN   NaN
# 21  15   NaN   NaN
# 22   8   1.0   NaN
# 23   9   9.0   9.0
# 24   5   5.0   NaN
# 25  13   NaN   NaN
# 26   1   1.0   6.0
# 27   6   NaN   NaN
# 28   1   NaN   NaN
# 29   5   9.0   NaN
# DataFrame saved to medium sized samples\orders_totes_24.csv
# medium sized samples\order_quantities_24.csv
#     0    1    2
# 0   2  NaN  NaN
# 1   2  1.0  1.0
# 2   2  1.0  3.0
# 3   3  3.0  1.0
# 4   1  NaN  NaN
# 5   2  1.0  1.0
# 6   1  1.0  NaN
# 7   3  3.0  1.0
# 8   3  1.0  2.0
# 9   1  2.0  1.0
# 10  2  1.0  2.0
# 11  3  2.0  1.0
# 12  3  NaN  NaN
# 13  1  2.0  1.0
# 14  3  1.0  2.0
# 15  1  NaN  NaN
# 16  2  NaN  NaN
# 17  3  NaN  NaN
# 18  3  1.0  2.0
# 19  3  NaN  NaN
# 20  2  NaN  NaN
# 21  2  NaN  NaN
# 22  2  1.0  NaN
# 23  3  3.0  3.0
# 24  2  3.0  NaN
# 25  3  NaN  NaN
# 26  3  3.0  3.0
# 27  3  NaN  NaN
# 28  2  NaN  NaN
# 29  1  2.0  NaN
# DataFrame saved to medium sized samples\order_quantities_24.csv
#
# === Dataset 25 (seed=2500) ===
#   n_orders=30, n_itemtypes=7, n_totes=20
# medium sized samples\order_itemtypes_25.csv
#     0    1    2
# 0   3  2.0  1.0
# 1   0  NaN  NaN
# 2   0  5.0  NaN
# 3   0  4.0  1.0
# 4   2  3.0  NaN
# 5   0  3.0  5.0
# 6   4  0.0  2.0
# 7   4  NaN  NaN
# 8   4  5.0  NaN
# 9   4  2.0  5.0
# 10  0  2.0  5.0
# 11  0  NaN  NaN
# 12  4  NaN  NaN
# 13  5  NaN  NaN
# 14  1  2.0  5.0
# 15  2  0.0  4.0
# 16  0  3.0  1.0
# 17  1  2.0  NaN
# 18  0  NaN  NaN
# 19  1  4.0  0.0
# 20  4  NaN  NaN
# 21  3  NaN  NaN
# 22  5  NaN  NaN
# 23  4  3.0  2.0
# 24  2  1.0  NaN
# 25  4  0.0  1.0
# 26  2  NaN  NaN
# 27  5  4.0  NaN
# 28  4  NaN  NaN
# 29  4  NaN  NaN
# DataFrame saved to medium sized samples\order_itemtypes_25.csv
# medium sized samples\orders_totes_25.csv
#      0     1     2
# 0   13   1.0  13.0
# 1   17   NaN   NaN
# 2   19  19.0   NaN
# 3   14   9.0   3.0
# 4   19  17.0   NaN
# 5    2  19.0   2.0
# 6    1   1.0  16.0
# 7   13   NaN   NaN
# 8    2   2.0   NaN
# 9   12  12.0  12.0
# 10   8  14.0  12.0
# 11  14   NaN   NaN
# 12   7   NaN   NaN
# 13   1   NaN   NaN
# 14   7   7.0   7.0
# 15  17   1.0  16.0
# 16  15   2.0  15.0
# 17  14  14.0   NaN
# 18   8   NaN   NaN
# 19   7   7.0   8.0
# 20  18   NaN   NaN
# 21  18   NaN   NaN
# 22   0   NaN   NaN
# 23  10   2.0  10.0
# 24   6   6.0   NaN
# 25  10  10.0  18.0
# 26   1   NaN   NaN
# 27   9   4.0   NaN
# 28  15   NaN   NaN
# 29   4   NaN   NaN
# DataFrame saved to medium sized samples\orders_totes_25.csv
# medium sized samples\order_quantities_25.csv
#     0    1    2
# 0   1  1.0  2.0
# 1   2  NaN  NaN
# 2   2  2.0  NaN
# 3   2  3.0  1.0
# 4   3  2.0  NaN
# 5   1  3.0  1.0
# 6   2  3.0  3.0
# 7   2  NaN  NaN
# 8   1  1.0  NaN
# 9   2  1.0  1.0
# 10  3  2.0  2.0
# 11  3  NaN  NaN
# 12  1  NaN  NaN
# 13  1  NaN  NaN
# 14  1  3.0  2.0
# 15  3  1.0  2.0
# 16  2  2.0  3.0
# 17  2  1.0  NaN
# 18  1  NaN  NaN
# 19  1  2.0  1.0
# 20  2  NaN  NaN
# 21  3  NaN  NaN
# 22  1  NaN  NaN
# 23  3  3.0  3.0
# 24  3  2.0  NaN
# 25  1  1.0  3.0
# 26  1  NaN  NaN
# 27  3  1.0  NaN
# 28  1  NaN  NaN
# 29  2  NaN  NaN
# DataFrame saved to medium sized samples\order_quantities_25.csv
#
# === Dataset 26 (seed=2600) ===
#   n_orders=34, n_itemtypes=8, n_totes=16
# medium sized samples\order_itemtypes_26.csv
#     0    1    2
# 0   3  1.0  0.0
# 1   5  NaN  NaN
# 2   4  6.0  NaN
# 3   0  2.0  4.0
# 4   6  4.0  NaN
# 5   5  3.0  2.0
# 6   1  6.0  NaN
# 7   4  NaN  NaN
# 8   1  NaN  NaN
# 9   5  1.0  4.0
# 10  5  0.0  NaN
# 11  4  NaN  NaN
# 12  5  6.0  3.0
# 13  6  NaN  NaN
# 14  5  1.0  3.0
# 15  2  4.0  3.0
# 16  0  NaN  NaN
# 17  4  NaN  NaN
# 18  4  0.0  NaN
# 19  0  3.0  NaN
# 20  6  3.0  NaN
# 21  2  4.0  3.0
# 22  4  NaN  NaN
# 23  5  4.0  NaN
# 24  6  4.0  3.0
# 25  0  6.0  NaN
# 26  5  1.0  NaN
# 27  2  3.0  5.0
# 28  0  1.0  NaN
# 29  1  NaN  NaN
# 30  2  6.0  NaN
# 31  3  NaN  NaN
# 32  1  NaN  NaN
# 33  3  NaN  NaN
# DataFrame saved to medium sized samples\order_itemtypes_26.csv
# medium sized samples\orders_totes_26.csv
#      0     1     2
# 0    5   4.0  13.0
# 1    1   NaN   NaN
# 2    3   2.0   NaN
# 3    9   9.0   1.0
# 4    0   2.0   NaN
# 5    5   3.0   5.0
# 6   12  12.0   NaN
# 7   15   NaN   NaN
# 8   10   NaN   NaN
# 9    4  11.0   2.0
# 10   4   4.0   NaN
# 11   9   NaN   NaN
# 12  14   5.0  14.0
# 13   9   NaN   NaN
# 14   1   1.0  14.0
# 15   5   5.0   5.0
# 16  12   NaN   NaN
# 17  10   NaN   NaN
# 18   0  11.0   NaN
# 19   0   0.0   NaN
# 20   9   9.0   NaN
# 21  11   8.0   3.0
# 22  11   NaN   NaN
# 23  12  12.0   NaN
# 24  15   6.0   4.0
# 25   3  12.0   NaN
# 26   0   0.0   NaN
# 27  15  15.0   7.0
# 28   0   0.0   NaN
# 29  13   NaN   NaN
# 30   3   3.0   NaN
# 31   4   NaN   NaN
# 32   3   NaN   NaN
# 33  12   NaN   NaN
# DataFrame saved to medium sized samples\orders_totes_26.csv
# medium sized samples\order_quantities_26.csv
#     0    1    2
# 0   3  3.0  1.0
# 1   1  NaN  NaN
# 2   2  2.0  NaN
# 3   2  3.0  1.0
# 4   2  1.0  NaN
# 5   1  3.0  3.0
# 6   3  1.0  NaN
# 7   3  NaN  NaN
# 8   1  NaN  NaN
# 9   3  1.0  3.0
# 10  3  3.0  NaN
# 11  1  NaN  NaN
# 12  3  3.0  1.0
# 13  3  NaN  NaN
# 14  3  1.0  3.0
# 15  2  1.0  3.0
# 16  3  NaN  NaN
# 17  3  NaN  NaN
# 18  2  2.0  NaN
# 19  3  1.0  NaN
# 20  1  3.0  NaN
# 21  2  2.0  2.0
# 22  1  NaN  NaN
# 23  2  3.0  NaN
# 24  1  3.0  1.0
# 25  2  2.0  NaN
# 26  2  2.0  NaN
# 27  3  3.0  3.0
# 28  1  3.0  NaN
# 29  1  NaN  NaN
# 30  1  1.0  NaN
# 31  3  NaN  NaN
# 32  3  NaN  NaN
# 33  3  NaN  NaN
# DataFrame saved to medium sized samples\order_quantities_26.csv
#
# === Dataset 27 (seed=2700) ===
#   n_orders=31, n_itemtypes=8, n_totes=17
# medium sized samples\order_itemtypes_27.csv
#     0    1    2
# 0   2  NaN  NaN
# 1   1  NaN  NaN
# 2   1  3.0  NaN
# 3   0  6.0  1.0
# 4   5  NaN  NaN
# 5   6  NaN  NaN
# 6   1  2.0  4.0
# 7   6  2.0  NaN
# 8   6  NaN  NaN
# 9   1  3.0  NaN
# 10  3  NaN  NaN
# 11  3  4.0  1.0
# 12  5  NaN  NaN
# 13  4  5.0  6.0
# 14  0  3.0  2.0
# 15  0  5.0  2.0
# 16  6  NaN  NaN
# 17  4  NaN  NaN
# 18  3  6.0  NaN
# 19  5  4.0  2.0
# 20  3  1.0  NaN
# 21  5  4.0  NaN
# 22  4  2.0  NaN
# 23  5  0.0  NaN
# 24  1  NaN  NaN
# 25  4  2.0  0.0
# 26  1  4.0  NaN
# 27  1  NaN  NaN
# 28  3  NaN  NaN
# 29  3  6.0  NaN
# 30  3  1.0  6.0
# DataFrame saved to medium sized samples\order_itemtypes_27.csv
# medium sized samples\orders_totes_27.csv
#      0     1     2
# 0    4   NaN   NaN
# 1   15   NaN   NaN
# 2    8   4.0   NaN
# 3   15   6.0   7.0
# 4   14   NaN   NaN
# 5   16   NaN   NaN
# 6   15  15.0  15.0
# 7    3   3.0   NaN
# 8    2   NaN   NaN
# 9    4   1.0   NaN
# 10   6   NaN   NaN
# 11  11   5.0  11.0
# 12  12   NaN   NaN
# 13  11  11.0  11.0
# 14   1   1.0   0.0
# 15   7  10.0   3.0
# 16   5   NaN   NaN
# 17   7   NaN   NaN
# 18  13  13.0   NaN
# 19   9   6.0  13.0
# 20   6   6.0   NaN
# 21   8   8.0   NaN
# 22   2  14.0   NaN
# 23  13  15.0   NaN
# 24  16   NaN   NaN
# 25  11  16.0  11.0
# 26   8  14.0   NaN
# 27   7   NaN   NaN
# 28  13   NaN   NaN
# 29  16  16.0   NaN
# 30   4   4.0  14.0
# DataFrame saved to medium sized samples\orders_totes_27.csv
# medium sized samples\order_quantities_27.csv
#     0    1    2
# 0   3  NaN  NaN
# 1   1  NaN  NaN
# 2   2  3.0  NaN
# 3   3  3.0  2.0
# 4   1  NaN  NaN
# 5   2  NaN  NaN
# 6   3  3.0  2.0
# 7   3  3.0  NaN
# 8   1  NaN  NaN
# 9   1  3.0  NaN
# 10  3  NaN  NaN
# 11  3  3.0  3.0
# 12  1  NaN  NaN
# 13  2  2.0  2.0
# 14  2  2.0  2.0
# 15  3  3.0  2.0
# 16  3  NaN  NaN
# 17  1  NaN  NaN
# 18  3  2.0  NaN
# 19  2  3.0  2.0
# 20  3  3.0  NaN
# 21  3  3.0  NaN
# 22  3  1.0  NaN
# 23  1  2.0  NaN
# 24  2  NaN  NaN
# 25  3  3.0  2.0
# 26  2  3.0  NaN
# 27  3  NaN  NaN
# 28  2  NaN  NaN
# 29  1  3.0  NaN
# 30  2  1.0  1.0
# DataFrame saved to medium sized samples\order_quantities_27.csv
#
# === Dataset 28 (seed=2800) ===
#   n_orders=35, n_itemtypes=8, n_totes=19
# medium sized samples\order_itemtypes_28.csv
#     0    1    2
# 0   2  6.0  1.0
# 1   4  NaN  NaN
# 2   4  1.0  NaN
# 3   4  NaN  NaN
# 4   6  NaN  NaN
# 5   1  NaN  NaN
# 6   1  6.0  NaN
# 7   2  NaN  NaN
# 8   2  NaN  NaN
# 9   0  1.0  3.0
# 10  0  2.0  5.0
# 11  1  2.0  NaN
# 12  0  4.0  1.0
# 13  1  0.0  NaN
# 14  0  NaN  NaN
# 15  6  2.0  NaN
# 16  0  6.0  NaN
# 17  3  0.0  NaN
# 18  0  NaN  NaN
# 19  4  NaN  NaN
# 20  1  NaN  NaN
# 21  0  NaN  NaN
# 22  2  1.0  3.0
# 23  1  0.0  NaN
# 24  4  0.0  NaN
# 25  5  NaN  NaN
# 26  2  0.0  NaN
# 27  3  NaN  NaN
# 28  0  NaN  NaN
# 29  2  5.0  4.0
# 30  0  4.0  NaN
# 31  4  0.0  NaN
# 32  6  NaN  NaN
# 33  0  2.0  1.0
# 34  6  2.0  NaN
# DataFrame saved to medium sized samples\order_itemtypes_28.csv
# medium sized samples\orders_totes_28.csv
#      0     1     2
# 0    4   4.0   4.0
# 1    7   NaN   NaN
# 2    6   1.0   NaN
# 3    3   NaN   NaN
# 4   16   NaN   NaN
# 5   17   NaN   NaN
# 6    2  11.0   NaN
# 7    3   NaN   NaN
# 8    0   NaN   NaN
# 9    1   7.0   1.0
# 10   8  13.0   8.0
# 11   9  18.0   NaN
# 12  18  18.0  18.0
# 13   4  11.0   NaN
# 14  14   NaN   NaN
# 15  17   8.0   NaN
# 16   2   2.0   NaN
# 17   7  13.0   NaN
# 18   7   NaN   NaN
# 19   6   NaN   NaN
# 20   0   NaN   NaN
# 21   6   NaN   NaN
# 22  13  13.0  11.0
# 23   2   2.0   NaN
# 24  15   2.0   NaN
# 25  17   NaN   NaN
# 26  11  11.0   NaN
# 27  12   NaN   NaN
# 28  10   NaN   NaN
# 29   4   1.0  12.0
# 30   9   9.0   NaN
# 31  15  15.0   NaN
# 32  15   NaN   NaN
# 33  17  17.0   6.0
# 34  16   2.0   NaN
# DataFrame saved to medium sized samples\orders_totes_28.csv
# medium sized samples\order_quantities_28.csv
#     0    1    2
# 0   2  3.0  1.0
# 1   2  NaN  NaN
# 2   2  3.0  NaN
# 3   3  NaN  NaN
# 4   2  NaN  NaN
# 5   1  NaN  NaN
# 6   1  2.0  NaN
# 7   3  NaN  NaN
# 8   1  NaN  NaN
# 9   3  3.0  3.0
# 10  2  2.0  1.0
# 11  1  2.0  NaN
# 12  1  1.0  3.0
# 13  3  3.0  NaN
# 14  1  NaN  NaN
# 15  3  3.0  NaN
# 16  3  3.0  NaN
# 17  1  3.0  NaN
# 18  2  NaN  NaN
# 19  3  NaN  NaN
# 20  3  NaN  NaN
# 21  3  NaN  NaN
# 22  1  1.0  1.0
# 23  1  2.0  NaN
# 24  2  1.0  NaN
# 25  1  NaN  NaN
# 26  1  3.0  NaN
# 27  3  NaN  NaN
# 28  1  NaN  NaN
# 29  3  2.0  2.0
# 30  1  2.0  NaN
# 31  2  2.0  NaN
# 32  1  NaN  NaN
# 33  2  1.0  3.0
# 34  1  3.0  NaN
# DataFrame saved to medium sized samples\order_quantities_28.csv
#
# === Dataset 29 (seed=2900) ===
#   n_orders=32, n_itemtypes=7, n_totes=20
# medium sized samples\order_itemtypes_29.csv
#     0    1    2
# 0   3  0.0  NaN
# 1   1  2.0  NaN
# 2   0  5.0  NaN
# 3   2  4.0  0.0
# 4   4  1.0  5.0
# 5   0  NaN  NaN
# 6   4  0.0  3.0
# 7   4  1.0  3.0
# 8   5  3.0  NaN
# 9   1  NaN  NaN
# 10  2  NaN  NaN
# 11  4  1.0  NaN
# 12  5  1.0  NaN
# 13  5  3.0  NaN
# 14  1  0.0  NaN
# 15  1  0.0  NaN
# 16  4  NaN  NaN
# 17  3  NaN  NaN
# 18  3  2.0  0.0
# 19  5  4.0  1.0
# 20  1  5.0  NaN
# 21  4  1.0  NaN
# 22  2  1.0  NaN
# 23  3  4.0  NaN
# 24  3  5.0  NaN
# 25  1  5.0  NaN
# 26  1  3.0  4.0
# 27  4  5.0  3.0
# 28  4  2.0  0.0
# 29  3  NaN  NaN
# 30  1  3.0  2.0
# 31  1  5.0  NaN
# DataFrame saved to medium sized samples\order_itemtypes_29.csv
# medium sized samples\orders_totes_29.csv
#      0     1     2
# 0    4   4.0   NaN
# 1   17  17.0   NaN
# 2   15  15.0   NaN
# 3    3  10.0  17.0
# 4   12   5.0  12.0
# 5   12   NaN   NaN
# 6   10   7.0   6.0
# 7   17   0.0  12.0
# 8   19  12.0   NaN
# 9   10   NaN   NaN
# 10  16   NaN   NaN
# 11  18   7.0   NaN
# 12   5  14.0   NaN
# 13  15   6.0   NaN
# 14   5   1.0   NaN
# 15  18  11.0   NaN
# 16   8   NaN   NaN
# 17  14   NaN   NaN
# 18  19   2.0  19.0
# 19   7   7.0   7.0
# 20   2   2.0   NaN
# 21  15  19.0   NaN
# 22   0   6.0   NaN
# 23  17   0.0   NaN
# 24  14  14.0   NaN
# 25   8  11.0   NaN
# 26   9   9.0   9.0
# 27   1   1.0  10.0
# 28   3   3.0   3.0
# 29  14   NaN   NaN
# 30  13   8.0  13.0
# 31   7  16.0   NaN
# DataFrame saved to medium sized samples\orders_totes_29.csv
# medium sized samples\order_quantities_29.csv
#     0    1    2
# 0   2  3.0  NaN
# 1   1  1.0  NaN
# 2   3  3.0  NaN
# 3   1  2.0  1.0
# 4   3  3.0  2.0
# 5   3  NaN  NaN
# 6   2  3.0  2.0
# 7   2  3.0  1.0
# 8   1  2.0  NaN
# 9   2  NaN  NaN
# 10  1  NaN  NaN
# 11  3  2.0  NaN
# 12  3  2.0  NaN
# 13  2  1.0  NaN
# 14  2  1.0  NaN
# 15  2  2.0  NaN
# 16  3  NaN  NaN
# 17  2  NaN  NaN
# 18  3  2.0  2.0
# 19  1  3.0  2.0
# 20  1  3.0  NaN
# 21  1  1.0  NaN
# 22  1  2.0  NaN
# 23  1  3.0  NaN
# 24  2  2.0  NaN
# 25  2  3.0  NaN
# 26  1  1.0  2.0
# 27  3  3.0  3.0
# 28  3  2.0  1.0
# 29  3  NaN  NaN
# 30  3  1.0  3.0
# 31  2  1.0  NaN
# DataFrame saved to medium sized samples\order_quantities_29.csv
#
# === Dataset 30 (seed=3000) ===
#   n_orders=35, n_itemtypes=7, n_totes=18
# medium sized samples\order_itemtypes_30.csv
#     0    1    2
# 0   2  NaN  NaN
# 1   2  1.0  3.0
# 2   5  1.0  4.0
# 3   4  5.0  NaN
# 4   2  4.0  NaN
# 5   5  NaN  NaN
# 6   1  2.0  NaN
# 7   1  NaN  NaN
# 8   3  5.0  0.0
# 9   0  4.0  3.0
# 10  5  1.0  2.0
# 11  1  NaN  NaN
# 12  1  2.0  5.0
# 13  1  NaN  NaN
# 14  4  NaN  NaN
# 15  3  0.0  1.0
# 16  2  NaN  NaN
# 17  4  0.0  1.0
# 18  5  2.0  1.0
# 19  1  NaN  NaN
# 20  2  NaN  NaN
# 21  1  0.0  3.0
# 22  3  4.0  NaN
# 23  4  0.0  5.0
# 24  5  NaN  NaN
# 25  0  NaN  NaN
# 26  1  0.0  NaN
# 27  0  NaN  NaN
# 28  3  5.0  2.0
# 29  2  NaN  NaN
# 30  5  2.0  NaN
# 31  5  4.0  NaN
# 32  5  NaN  NaN
# 33  1  2.0  0.0
# 34  3  0.0  1.0
# DataFrame saved to medium sized samples\order_itemtypes_30.csv
# medium sized samples\orders_totes_30.csv
#      0     1     2
# 0   15   NaN   NaN
# 1   10  10.0  10.0
# 2   11  10.0   7.0
# 3   12  12.0   NaN
# 4    6   6.0   NaN
# 5    8   NaN   NaN
# 6   10  10.0   NaN
# 7    7   NaN   NaN
# 8    0   8.0  14.0
# 9    3  11.0   9.0
# 10  12   8.0  12.0
# 11   1   NaN   NaN
# 12  17  14.0  10.0
# 13  15   NaN   NaN
# 14   0   NaN   NaN
# 15   0  13.0  11.0
# 16  14   NaN   NaN
# 17   8   9.0  12.0
# 18   9   9.0   9.0
# 19   6   NaN   NaN
# 20  16   NaN   NaN
# 21   7   7.0   7.0
# 22   5   5.0   NaN
# 23   8  16.0   8.0
# 24   2   NaN   NaN
# 25   4   NaN   NaN
# 26  11  11.0   NaN
# 27   8   NaN   NaN
# 28   3   3.0  16.0
# 29  14   NaN   NaN
# 30  14  14.0   NaN
# 31  14  14.0   NaN
# 32   4   NaN   NaN
# 33   3   3.0   3.0
# 34  15  15.0  15.0
# DataFrame saved to medium sized samples\orders_totes_30.csv
# medium sized samples\order_quantities_30.csv
#     0    1    2
# 0   3  NaN  NaN
# 1   2  1.0  1.0
# 2   3  3.0  3.0
# 3   3  2.0  NaN
# 4   2  2.0  NaN
# 5   2  NaN  NaN
# 6   3  2.0  NaN
# 7   1  NaN  NaN
# 8   1  3.0  3.0
# 9   1  2.0  2.0
# 10  3  1.0  1.0
# 11  2  NaN  NaN
# 12  1  2.0  1.0
# 13  3  NaN  NaN
# 14  3  NaN  NaN
# 15  3  3.0  1.0
# 16  1  NaN  NaN
# 17  2  3.0  2.0
# 18  1  1.0  3.0
# 19  2  NaN  NaN
# 20  2  NaN  NaN
# 21  2  3.0  3.0
# 22  2  1.0  NaN
# 23  2  3.0  1.0
# 24  2  NaN  NaN
# 25  3  NaN  NaN
# 26  3  1.0  NaN
# 27  2  NaN  NaN
# 28  3  1.0  3.0
# 29  2  NaN  NaN
# 30  3  1.0  NaN
# 31  3  1.0  NaN
# 32  2  NaN  NaN
# 33  2  1.0  2.0
# 34  1  1.0  3.0
# DataFrame saved to medium sized samples\order_quantities_30.csv

# %% [markdown]
# # The list of order_itemtypes
# In this list, element [i][j] indicates the itemstype to which the jth item of order i has been assigned.

# %% [markdown]
# The number of iteams from each itemtype in each order is a random integer between 0 and 3

# %%
# (Moved into the main generation loop in the cell above)

# %% [markdown]
# # The list of order_totes
# In this list, element [i][j] indicates the tote to which the jth item of order i has been assigned.

# %% [markdown]
# There is a 50% probability that each subsequent item will be assigned to the same tote as the first item.

# %%
# (Moved into the main generation loop above)

# %%
# (Moved into the main generation loop above)
